# %% [markdown]
# # финальный проект.Промышленность

# %% [markdown]
# <div style=" padding: 30px 25px; border: 3px #FFBF73 solid">
# <p style="font-weight: 900; text-align: center;">  Задача  помочь заказчику уменьшить расход электроэнергии на производстве с помощью ML модели.
#
#  - нужно загрузить данные из БД SQL
#  - обработать,проанализировать данные
#  -  на основе анализа создать ML модель для предсказания температуры сплава на разных этапах производства

# %% [markdown]
# <div style=" padding: 30px 25px; border: 3px #FFBF73 solid">
# <p style="font-weight: 900; text-align: center;"> Описание данных </p>
#
#
# __Данные хранятся в базе данных PostgreSQL. Она состоит из нескольких таблиц__:
#
#     steel.data_arc — данные об электродах;
#     steel.data_bulk — данные об объёме сыпучих материалов;
#     steel.data_bulk_time — данные о времени подачи сыпучих материалов;
#     steel.data_gas — данные о продувке сплава газом;
#     steel.data_temp — данные об измерениях температуры;
#     steel.data_wire — данные об объёме проволочных материалов;
#     steel.data_wire_time — данные о времени подачи проволочных материалов.
#
# __key — номер партии. В таблицах может быть несколько строк с одинаковым значением key: они соответствуют разным итерациям обработки.__
#
# __Таблица steel.data_arc__
#    - BeginHeat — время начала нагрева;
#    - EndHeat — время окончания нагрева;
#    - ActivePower — значение активной мощности;
#    - ReactivePower — значение реактивной мощности.
#
#
# __Таблица steel.data_bulk__
#    - Bulk1 … Bulk15 — объём подаваемого материала.
#
# __Таблица steel.data_bulk_time__
#    - Bulk1 … Bulk15 — время подачи материала.
#
#
# __Таблица steel.data_gas__
#    - gas — объём подаваемого газа.
#
#
# __Таблица steel.data_temp__
#    - MesaureTime — время замера;
#    - Temperature — значение температуры.
#
#
# __Таблица steel.data_wire__
#    - Wire1 … Wire15 — объём подаваемых проволочных материалов.
#
#
# __Таблица steel.data_wire_time__
#    - Wire1 … Wire15 — время подачи проволочных материалов.

# %% [markdown]
# <div style="font-size:30px ;padding: 30px 25px; background-color:#7AD1FF ;solid;font-weight:400">
#
# <p style="font-weight: bold; text-align: center;">  импорт библиотек </p>

# %%
from IPython.core.display import display, HTML


import pandas as pd
import numpy as np
from sqlalchemy import create_engine 
import matplotlib.pyplot as plt
import seaborn as sns

import torch
import torch.nn.init as init
import torch.nn as nn
from torch import tensor
from torch.optim import Adam
from torch.utils.data import DataLoader, TensorDataset

from sklearn.metrics import mean_absolute_error,r2_score

from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler

from sklearn.dummy import DummyRegressor

from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression,Lasso
from catboost import CatBoostRegressor

import warnings

# %%
display(HTML("<style>.container { width:100% !important; }</style>"))

warnings.filterwarnings("ignore")

SEED = 141123
torch.manual_seed(141123);
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# <div style="font-size:30px ;padding: 30px 25px; background-color:#7AD1FF ;solid;font-weight:400">
# <p style="font-weight: bold; text-align: center;">   функции

# %%
def data_analis (df,  i  = True,
                  h  = True,
                  ds = True,
                  dp = True,
                  isna=True):
    if i == True:
        i=df.info()
        i

    if h == True:
        h = df.head()
        display(h)

    if ds == True:
        ds = df.describe()
        display(ds)
    print()
    if dp == True:
        dp = df.duplicated().sum()
        print('дубликаты:',dp)

    if isna == True:
        isna = df.isna().sum()
        miss = df.isna().sum() * 100 / len(df)
        display(pd.DataFrame({'пропуски':isna,'% потерь':miss},dtype=int))

# %%
def merger_by_key_inner(t1, t2):
    
    #merge dfs
    merged = t1.merge(right=t2,
            how='inner',
            on='key')
    
    return merged

# %% [markdown]
# <div style="font-size:30px ;padding: 30px 25px; background-color:#7AD1FF ;solid;font-weight:400">
# <p style="font-weight: bold; text-align: center;"> Глава 1. загрузка и просмотр данных

# %%
db_config = {
'user': 'praktikum_student',# имя пользователя
'pwd': 'Sdf4$2;d-d30pp',# пароль
'host': 'rc1b-wcoijxj3yxfsf3fs.mdb.yandexcloud.net',
'port': 6432,# порт подключения
'db': 'data-science-final'# название базы данных,
}

connection_string = 'postgresql://{}:{}@{}:{}/{}'.format(
    db_config['user'],
    db_config['pwd'],
    db_config['host'],
    db_config['port'],
    db_config['db'],
)

# %%
engine = create_engine(connection_string)

# %%
query = '''
SELECT table_name
FROM information_schema.tables
WHERE table_type = 'BASE TABLE' AND table_schema= 'steel'
'''
sample_df=pd.read_sql_query(query, con=engine)

# %%
display(sample_df)
# Out:
#        table_name
# 0        data_arc
# 1       data_bulk
# 2  data_bulk_time
# 3        data_gas
# 4       data_temp
# 5       data_wire
# 6  data_wire_time

# %%
query = '''
SELECT *
FROM steel.data_arc
'''

arc = pd.read_sql_query(query, con=engine)

# %%
data_analis(arc)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14876 entries, 0 to 14875
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   key            14876 non-null  int64
#  1   BeginHeat      14876 non-null  object
#  2   EndHeat        14876 non-null  object
#  3   ActivePower    14876 non-null  float64
#  4   ReactivePower  14876 non-null  float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 581.2+ KB
#    key BeginHeat   EndHeat  ActivePower  ReactivePower
# 0    1  11:02:14  11:06:02     0.976059       0.687084
# 1    1  11:07:28  11:10:33     0.805607       0.520285
# 2    1  11:11:44  11:14:36     0.744363       0.498805
# 3    1  11:18:14  11:24:19     1.659363       1.062669
# 4    1  11:26:09  11:28:37     0.692755       0.414397
#                 key   ActivePower  ReactivePower
# count  14876.000000  14876.000000   14876.000000
# mean    1615.220422      0.670441       0.452592
# std      934.571502      0.408159       5.878702
# min        1.000000      0.030002    -715.504924
# 25%      806.000000      0.395297       0.290991
# 50%     1617.000000      0.555517       0.415962
# 75%     2429.000000      0.857034       0.637371
# max     3241.000000      3.731596       2.676388
# дубликаты: 0
#                пропуски  % потерь
# key                   0         0
# BeginHeat             0         0
# EndHeat               0         0
# ActivePower           0         0
# ReactivePower         0         0

# %%
query = '''
SELECT *
FROM steel.data_bulk
'''

bulk = pd.read_sql_query(query, con=engine)

# %%
data_analis(bulk)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3129 entries, 0 to 3128
# Data columns (total 16 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   key      3129 non-null   int64
#  1   Bulk 1   252 non-null    float64
#  2   Bulk 2   22 non-null     float64
#  3   Bulk 3   1298 non-null   float64
#  4   Bulk 4   1014 non-null   float64
#  5   Bulk 5   77 non-null     float64
#  6   Bulk 6   576 non-null    float64
#  7   Bulk 7   25 non-null     float64
#  8   Bulk 8   1 non-null      float64
#  9   Bulk 9   19 non-null     float64
#  10  Bulk 10  176 non-null    float64
#  11  Bulk 11  177 non-null    float64
#  12  Bulk 12  2450 non-null   float64
#  13  Bulk 13  18 non-null     float64
#  14  Bulk 14  2806 non-null   float64
#  15  Bulk 15  2248 non-null   float64
# dtypes: float64(15), int64(1)
# memory usage: 391.2 KB
#    key  Bulk 1  Bulk 2  Bulk 3  Bulk 4  Bulk 5  Bulk 6  Bulk 7  Bulk 8  \
# 0    1     NaN     NaN     NaN    43.0     NaN     NaN     NaN     NaN
# 1    2     NaN     NaN     NaN    73.0     NaN     NaN     NaN     NaN
# 2    3     NaN     NaN     NaN    34.0     NaN     NaN     NaN     NaN
# 3    4     NaN     NaN     NaN    81.0     NaN     NaN     NaN     NaN
# 4    5     NaN     NaN     NaN    78.0     NaN     NaN     NaN     NaN
#
#    Bulk 9  Bulk 10  Bulk 11  Bulk 12  Bulk 13  Bulk 14  Bulk 15
# 0     NaN      NaN      NaN    206.0      NaN    150.0    154.0
# 1     NaN      NaN      NaN    206.0      NaN    149.0    154.0
# 2     NaN      NaN      NaN    205.0      NaN    152.0    153.0
# 3     NaN      NaN      NaN    207.0      NaN    153.0    154.0
# 4     NaN      NaN      NaN    203.0      NaN    151.0    152.0
#                key      Bulk 1      Bulk 2       Bulk 3       Bulk 4  \
# count  3129.000000  252.000000   22.000000  1298.000000  1014.000000
# mean   1624.383509   39.242063  253.045455   113.879045   104.394477
# std     933.337642   18.277654   21.180578    75.483494    48.184126
# min       1.000000   10.000000  228.000000     6.000000    12.000000
# 25%     816.000000   27.000000  242.000000    58.000000    72.000000
# 50%    1622.000000   31.000000  251.500000    97.500000   102.000000
# 75%    2431.000000   46.000000  257.750000   152.000000   133.000000
# max    3241.000000  185.000000  325.000000   454.000000   281.000000
#
#            Bulk 5      Bulk 6      Bulk 7  Bulk 8      Bulk 9     Bulk 10  \
# count   77.000000  576.000000   25.000000     1.0   19.000000  176.000000
# mean   107.025974  118.925347  305.600000    49.0   76.315789   83.284091
# std     81.790646   72.057776  191.022904     NaN   21.720581   26.060347
# min     11.000000   17.000000   47.000000    49.0   63.000000   24.000000
# 25%     70.000000   69.750000  155.000000    49.0   66.000000   64.000000
# 50%     86.000000  100.000000  298.000000    49.0   68.000000   86.500000
# 75%    132.000000  157.000000  406.000000    49.0   70.500000  102.000000
# max    603.000000  503.000000  772.000000    49.0  147.000000  159.000000
#
#           Bulk 11      Bulk 12     Bulk 13      Bulk 14      Bulk 15
# count  177.000000  2450.000000   18.000000  2806.000000  2248.000000
# mean    76.819209   260.471020  181.111111   170.284747   160.513345
# std     59.655365   120.649269   46.088009    65.868652    51.765319
# min      8.000000    53.000000  151.000000    16.000000     1.000000
# 25%     25.000000   204.000000  153.250000   119.000000   105.000000
# 50%     64.000000   208.000000  155.500000   151.000000   160.000000
# 75%    106.000000   316.000000  203.500000   205.750000   205.000000
# max    313.000000  1849.000000  305.000000   636.000000   405.000000
# дубликаты: 0
#          пропуски  % потерь
# key             0         0
# Bulk 1       2877        91
# Bulk 2       3107        99
# Bulk 3       1831        58
# Bulk 4       2115        67
# Bulk 5       3052        97
# Bulk 6       2553        81
# Bulk 7       3104        99
# Bulk 8       3128        99
# Bulk 9       3110        99
# Bulk 10      2953        94
# Bulk 11      2952        94
# Bulk 12       679        21
# Bulk 13      3111        99
# Bulk 14       323        10
# Bulk 15       881        28

# %%
query = '''
SELECT *
FROM steel.data_bulk_time
'''

bulk_time = pd.read_sql_query(query, con=engine)

# %%
data_analis(bulk_time)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3129 entries, 0 to 3128
# Data columns (total 16 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   key      3129 non-null   int64
#  1   Bulk 1   252 non-null    object
#  2   Bulk 2   22 non-null     object
#  3   Bulk 3   1298 non-null   object
#  4   Bulk 4   1014 non-null   object
#  5   Bulk 5   77 non-null     object
#  6   Bulk 6   576 non-null    object
#  7   Bulk 7   25 non-null     object
#  8   Bulk 8   1 non-null      object
#  9   Bulk 9   19 non-null     object
#  10  Bulk 10  176 non-null    object
#  11  Bulk 11  177 non-null    object
#  12  Bulk 12  2450 non-null   object
#  13  Bulk 13  18 non-null     object
#  14  Bulk 14  2806 non-null   object
#  15  Bulk 15  2248 non-null   object
# dtypes: int64(1), object(15)
# memory usage: 391.2+ KB
#    key Bulk 1 Bulk 2 Bulk 3    Bulk 4 Bulk 5 Bulk 6 Bulk 7 Bulk 8 Bulk 9  \
# 0    1   None   None   None  11:21:30   None   None   None   None   None
# 1    2   None   None   None  11:46:38   None   None   None   None   None
# 2    3   None   None   None  12:31:06   None   None   None   None   None
# 3    4   None   None   None  12:48:43   None   None   None   None   None
# 4    5   None   None   None  13:18:50   None   None   None   None   None
#
#   Bulk 10 Bulk 11   Bulk 12 Bulk 13   Bulk 14   Bulk 15
# 0    None    None  11:03:52    None  11:03:52  11:03:52
# 1    None    None  11:40:20    None  11:40:20  11:40:20
# 2    None    None  12:09:40    None  12:09:40  12:09:40
# 3    None    None  12:41:24    None  12:41:24  12:41:24
# 4    None    None  13:12:56    None  13:12:56  13:12:56
#                key
# count  3129.000000
# mean   1624.383509
# std     933.337642
# min       1.000000
# 25%     816.000000
# 50%    1622.000000
# 75%    2431.000000
# max    3241.000000
# дубликаты: 0
#          пропуски  % потерь
# key             0         0
# Bulk 1       2877        91
# Bulk 2       3107        99
# Bulk 3       1831        58
# Bulk 4       2115        67
# Bulk 5       3052        97
# Bulk 6       2553        81
# Bulk 7       3104        99
# Bulk 8       3128        99
# Bulk 9       3110        99
# Bulk 10      2953        94
# Bulk 11      2952        94
# Bulk 12       679        21
# Bulk 13      3111        99
# Bulk 14       323        10
# Bulk 15       881        28

# %%
query = '''
SELECT *
FROM steel.data_gas
'''

gas = pd.read_sql_query(query, con=engine)

# %%
data_analis(gas)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3239 entries, 0 to 3238
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3239 non-null   int64
#  1   gas     3239 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 50.7 KB
#    key        gas
# 0    1  29.749986
# 1    2  12.555561
# 2    3  28.554793
# 3    4  18.841219
# 4    5   5.413692
#                key          gas
# count  3239.000000  3239.000000
# mean   1621.861377    11.002062
# std     935.386334     6.220327
# min       1.000000     0.008399
# 25%     812.500000     7.043089
# 50%    1622.000000     9.836267
# 75%    2431.500000    13.769915
# max    3241.000000    77.995040
# дубликаты: 0
#      пропуски  % потерь
# key         0         0
# gas         0         0

# %%
query = '''
SELECT *
FROM steel.data_temp
'''

temp = pd.read_sql_query(query, con=engine)

# %%
data_analis(temp)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15907 entries, 0 to 15906
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   key          15907 non-null  int64
#  1   MesaureTime  15907 non-null  object
#  2   Temperature  13006 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 372.9+ KB
#    key MesaureTime  Temperature
# 0    1    11:16:18       1571.0
# 1    1    11:25:53       1604.0
# 2    1    11:29:11       1618.0
# 3    1    11:30:01       1601.0
# 4    1    11:30:39       1613.0
#                 key   Temperature
# count  15907.000000  13006.000000
# mean    1607.880870   1591.840920
# std      942.212073     21.375851
# min        1.000000   1191.000000
# 25%      790.000000   1581.000000
# 50%     1618.000000   1591.000000
# 75%     2427.000000   1601.000000
# max     3241.000000   1705.000000
# дубликаты: 0
#              пропуски  % потерь
# key                 0         0
# MesaureTime         0         0
# Temperature      2901        18

# %%
query = '''
SELECT *
FROM steel.data_wire
'''

wire = pd.read_sql_query(query, con=engine)

# %%
data_analis(wire)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3081 entries, 0 to 3080
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3081 non-null   int64
#  1   Wire 1  3055 non-null   float64
#  2   Wire 2  1079 non-null   float64
#  3   Wire 3  63 non-null     float64
#  4   Wire 4  14 non-null     float64
#  5   Wire 5  1 non-null      float64
#  6   Wire 6  73 non-null     float64
#  7   Wire 7  11 non-null     float64
#  8   Wire 8  19 non-null     float64
#  9   Wire 9  29 non-null     float64
# dtypes: float64(9), int64(1)
# memory usage: 240.8 KB
#    key     Wire 1   Wire 2  Wire 3  Wire 4  Wire 5  Wire 6  Wire 7  Wire 8  \
# 0    1  60.059998      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1    2  96.052315      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2    3  91.160157      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3    4  89.063515      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4    5  89.238236  9.11456     NaN     NaN     NaN     NaN     NaN     NaN
#
#    Wire 9
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#                key       Wire 1       Wire 2      Wire 3      Wire 4  Wire 5  \
# count  3081.000000  3055.000000  1079.000000   63.000000   14.000000   1.000
# mean   1623.426485   100.895853    50.577323  189.482681   57.442841  15.132
# std     932.996726    42.012518    39.320216   99.513444   28.824667     NaN
# min       1.000000     1.918800     0.030160    0.144144   24.148801  15.132
# 25%     823.000000    72.115684    20.193680   95.135044   40.807002  15.132
# 50%    1619.000000   100.158234    40.142956  235.194977   45.234282  15.132
# 75%    2434.000000   126.060484    70.227558  276.252014   76.124619  15.132
# max    3241.000000   330.314424   282.780152  385.008668  113.231044  15.132
#
#            Wire 6     Wire 7      Wire 8     Wire 9
# count   73.000000  11.000000   19.000000  29.000000
# mean    48.016974  10.039007   53.625193  34.155752
# std     33.919845   8.610584   16.881728  19.931616
# min      0.034320   0.234208   45.076721   4.622800
# 25%     25.053600   6.762756   46.094879  22.058401
# 50%     42.076324   9.017009   46.279999  30.066399
# 75%     64.212723  11.886057   48.089603  43.862003
# max    180.454575  32.847674  102.762401  90.053604
# дубликаты: 0
#         пропуски  % потерь
# key            0         0
# Wire 1        26         0
# Wire 2      2002        64
# Wire 3      3018        97
# Wire 4      3067        99
# Wire 5      3080        99
# Wire 6      3008        97
# Wire 7      3070        99
# Wire 8      3062        99
# Wire 9      3052        99

# %%
query = '''
SELECT *
FROM steel.data_wire_time
'''

wire_time = pd.read_sql_query(query, con=engine)

# %%
data_analis(wire_time)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3081 entries, 0 to 3080
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3081 non-null   int64
#  1   Wire 1  3055 non-null   object
#  2   Wire 2  1079 non-null   object
#  3   Wire 3  63 non-null     object
#  4   Wire 4  14 non-null     object
#  5   Wire 5  1 non-null      object
#  6   Wire 6  73 non-null     object
#  7   Wire 7  11 non-null     object
#  8   Wire 8  19 non-null     object
#  9   Wire 9  29 non-null     object
# dtypes: int64(1), object(9)
# memory usage: 240.8+ KB
#    key    Wire 1    Wire 2 Wire 3 Wire 4 Wire 5 Wire 6 Wire 7 Wire 8 Wire 9
# 0    1  11:11:41      None   None   None   None   None   None   None   None
# 1    2  11:46:10      None   None   None   None   None   None   None   None
# 2    3  12:13:47      None   None   None   None   None   None   None   None
# 3    4  12:48:05      None   None   None   None   None   None   None   None
# 4    5  13:18:15  13:32:06   None   None   None   None   None   None   None
#                key
# count  3081.000000
# mean   1623.426485
# std     932.996726
# min       1.000000
# 25%     823.000000
# 50%    1619.000000
# 75%    2434.000000
# max    3241.000000
# дубликаты: 0
#         пропуски  % потерь
# key            0         0
# Wire 1        26         0
# Wire 2      2002        64
# Wire 3      3018        97
# Wire 4      3067        99
# Wire 5      3080        99
# Wire 6      3008        97
# Wire 7      3070        99
# Wire 8      3062        99
# Wire 9      3052        99

# %% [markdown]
# <div style="padding: 30px 25px; border: 3px #7AD1FF solid">
#
# <p style="font-weight: bold; text-align: center;"> вывод <p>
#
#  - данные были успешно загруженны
#   - в таблице data_arc наблюдаются аномальные значения в столбцах ActivePower и ReactivePower, скорее всего эти мощьности должны
#     быть в пределе от 0 до 1, но не как ни в передах от -715 до 3. Также нужно изменить тип данных в столбцах BeginHeat и  EndHeat
#     на datetime
#   - в таблице data_bulk присутствуют дубликаты, а также Огромноге количество пропусков, эти пропуски можно заменить 0 т.к. в данной таблице пропуск означает, что материал не подавался .
#   - в таблице data_bulk_time тоже много пропусков, думаю их можно тоже заменить на 0.
#   - в таблице data_gas все хорошо, но судя по всему есть аномальные значения
#   - в таблице data_temp присутствуют дубликаты и отсутствут некоторые значения температур
#   - в таблице data_wire какое то невероятное количество пропусов, хоть бери и удаляй все столбы с 3 по 9. Присутствуют дубликаты и аномалии (по моему мнению обьем материала дан в процентах т.е. от 0 до 100)
#   - в таблице data_wire_time ситуация не лучше, тоже много пропусов и тоже присутствуют дубликаты.

# %% [markdown]
# <div style="font-size:30px ;padding: 30px 25px; background-color:#7AD1FF ;solid;font-weight:400">
# <p style="font-weight: bold; text-align: center;"> Глава 2. Обработка и исследовательский анализ

# %%
print('Кол-во строк до удаления:', len(arc))

arc = arc.drop(index=arc[arc['ReactivePower'] < 0].index)

print('Кол-во после удаления:', len(arc))
# Out:
# Кол-во строк до удаления: 14876
# Кол-во после удаления: 14875

# %%
arc['BeginHeat'] = pd.to_timedelta(arc['BeginHeat'].astype(str))
arc['EndHeat']=pd.to_timedelta(arc['EndHeat'].astype(str))

# %%
arc['FullPower']= np.sqrt(arc['ReactivePower']**2+arc['ActivePower']**2)

# %%
arc
# Out:
#         key       BeginHeat         EndHeat  ActivePower  ReactivePower  \
# 0         1 0 days 11:02:14 0 days 11:06:02     0.976059       0.687084
# 1         1 0 days 11:07:28 0 days 11:10:33     0.805607       0.520285
# 2         1 0 days 11:11:44 0 days 11:14:36     0.744363       0.498805
# 3         1 0 days 11:18:14 0 days 11:24:19     1.659363       1.062669
# 4         1 0 days 11:26:09 0 days 11:28:37     0.692755       0.414397
# ...     ...             ...             ...          ...            ...
# 14871  3241 0 days 03:58:58 0 days 04:01:35     0.533670       0.354439
# 14872  3241 0 days 04:05:04 0 days 04:08:04     0.676604       0.523631
# 14873  3241 0 days 04:16:41 0 days 04:19:45     0.733899       0.475654
# 14874  3241 0 days 04:31:51 0 days 04:32:48     0.220694       0.145768
# 14875  3241 0 days 04:34:47 0 days 04:36:08     0.306580       0.196708
#
#        FullPower
# 0       1.193639
# 1       0.959010
# 2       0.896038
# 3       1.970470
# 4       0.807239
# ...          ...
# 14871   0.640648
# 14872   0.855559
# 14873   0.874560
# 14874   0.264489
# 14875   0.364260
#
# [14875 rows x 6 columns]

# %%
bulk_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3129 entries, 0 to 3128
# Data columns (total 16 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   key      3129 non-null   int64
#  1   Bulk 1   252 non-null    object
#  2   Bulk 2   22 non-null     object
#  3   Bulk 3   1298 non-null   object
#  4   Bulk 4   1014 non-null   object
#  5   Bulk 5   77 non-null     object
#  6   Bulk 6   576 non-null    object
#  7   Bulk 7   25 non-null     object
#  8   Bulk 8   1 non-null      object
#  9   Bulk 9   19 non-null     object
#  10  Bulk 10  176 non-null    object
#  11  Bulk 11  177 non-null    object
#  12  Bulk 12  2450 non-null   object
#  13  Bulk 13  18 non-null     object
#  14  Bulk 14  2806 non-null   object
#  15  Bulk 15  2248 non-null   object
# dtypes: int64(1), object(15)
# memory usage: 391.2+ KB

# %%
bulk=bulk.drop_duplicates()
bulk=bulk.drop(['Bulk 1','Bulk 2','Bulk 5','Bulk 7','Bulk 8','Bulk 9','Bulk 10','Bulk 11','Bulk 13'],axis=1)
bulk_time=bulk_time.drop_duplicates()
bulk_time=bulk_time.drop(['Bulk 1','Bulk 2','Bulk 5','Bulk 7','Bulk 8','Bulk 9','Bulk 10','Bulk 11','Bulk 13'],axis=1)
bulk=bulk.fillna(0)
bulk_time=bulk_time.fillna(0)

print(bulk.isna().sum(),
      bulk_time.isna().sum())
# Out:
# key        0
# Bulk 3     0
# Bulk 4     0
# Bulk 6     0
# Bulk 12    0
# Bulk 14    0
# Bulk 15    0
# dtype: int64 key        0
# Bulk 3     0
# Bulk 4     0
# Bulk 6     0
# Bulk 12    0
# Bulk 14    0
# Bulk 15    0
# dtype: int64

# %%
bulk_time['Bulk 3']=pd.to_timedelta(bulk_time['Bulk 3'].astype(str))
bulk_time['Bulk 4']=pd.to_timedelta(bulk_time['Bulk 4'].astype(str))
bulk_time['Bulk 6']=pd.to_timedelta(bulk_time['Bulk 6'].astype(str))
bulk_time['Bulk 12']=pd.to_timedelta(bulk_time['Bulk 12'].astype(str))
bulk_time['Bulk 14']=pd.to_timedelta(bulk_time['Bulk 14'].astype(str))
bulk_time['Bulk 15']=pd.to_timedelta(bulk_time['Bulk 15'].astype(str))

# %%
temp= temp.dropna()
temp.isna().sum()
temp = temp.drop(index=temp[temp['Temperature']<1500].index)

# %%
temp['MesaureTime']=pd.to_datetime(temp['MesaureTime'],format='%H:%M:%S')

# %%
wire_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3081 entries, 0 to 3080
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3081 non-null   int64
#  1   Wire 1  3055 non-null   object
#  2   Wire 2  1079 non-null   object
#  3   Wire 3  63 non-null     object
#  4   Wire 4  14 non-null     object
#  5   Wire 5  1 non-null      object
#  6   Wire 6  73 non-null     object
#  7   Wire 7  11 non-null     object
#  8   Wire 8  19 non-null     object
#  9   Wire 9  29 non-null     object
# dtypes: int64(1), object(9)
# memory usage: 240.8+ KB

# %%
wire=wire.drop_duplicates()
wire=wire.drop(['Wire 3','Wire 4','Wire 5','Wire 6','Wire 7','Wire 8','Wire 9'],axis=1)
wire_time= wire_time.drop_duplicates()
wire_time=wire_time.drop(['Wire 3','Wire 4','Wire 5','Wire 6','Wire 7','Wire 8','Wire 9'],axis=1)
wire=wire.fillna(0)
wire_time=wire_time.fillna(0)

print(wire.isna().sum(),
      wire_time.isna().sum())
# Out:
# key       0
# Wire 1    0
# Wire 2    0
# dtype: int64 key       0
# Wire 1    0
# Wire 2    0
# dtype: int64

# %%
data = arc['ReactivePower']

plt.figure(figsize=(19,5))
plt.hist(data, bins=100)
plt.xlabel('Реактивная мощность', fontsize=18)
plt.xticks(fontsize=16)
plt.ylabel('Количество', fontsize=18)
plt.yticks(fontsize=16)
plt.title('Распределение реактивной мощности', fontsize=20)
plt.show()

# %%
wire_time['Wire 1']=pd.to_timedelta(wire_time['Wire 1'].astype(str))
wire_time['Wire 2']=pd.to_timedelta(wire_time['Wire 2'].astype(str))

# %%
data = arc['ActivePower']

plt.figure(figsize=(19,5))
plt.hist(data, bins=100)
plt.xlabel('активная мощность', fontsize=18)
plt.xticks(fontsize=16)
plt.ylabel('Количество', fontsize=18)
plt.yticks(fontsize=16)
plt.title('Распределение активной мощности', fontsize=20)
plt.show()

# %%
data = arc['FullPower']

plt.figure(figsize=(19,5))
plt.hist(data, bins=100)
plt.xlabel('Полная мощность', fontsize=18)
plt.xticks(fontsize=16)
plt.ylabel('Количество', fontsize=18)
plt.yticks(fontsize=16)
plt.title('Распределение полной мощности', fontsize=20)
plt.show()

# %%
arc = arc.drop(['ActivePower','ReactivePower'], axis=1)
arc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14875 entries, 0 to 14875
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   key        14875 non-null  int64
#  1   BeginHeat  14875 non-null  timedelta64[ns]
#  2   EndHeat    14875 non-null  timedelta64[ns]
#  3   FullPower  14875 non-null  float64
# dtypes: float64(1), int64(1), timedelta64[ns](2)
# memory usage: 581.1 KB

# %%
key= wire.drop('key',axis=1)
plt.figure(figsize=(10,10))
sns.boxplot(data=key, orient="h")
plt.title('Объем проволочных материалов')
plt.xlabel('Объем')
plt.ylabel('Материал')

plt.show()

# %%
key=bulk.drop('key',axis=1)
plt.figure(figsize=(12,9))
sns.boxplot(data=key,orient="h")
plt.title('количество подаваемой присадки')
plt.xlabel('количество')
plt.ylabel('номер присадки')
plt.grid();

# %%
key=temp.drop('key',axis=1)
plt.figure(figsize=(10,10))
sns.histplot(data=key,bins=100)
plt.title('Температура нагрева')
plt.xlabel('Градусы')
plt.ylabel('Показатель')

plt.show()

# %%
arc['warm_time'] = (arc['EndHeat'] - arc['BeginHeat']).dt.seconds
arc = arc.drop(['BeginHeat','EndHeat'], axis=1)
arc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14875 entries, 0 to 14875
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   key        14875 non-null  int64
#  1   FullPower  14875 non-null  float64
#  2   warm_time  14875 non-null  int64
# dtypes: float64(1), int64(2)
# memory usage: 464.8 KB

# %%
plt.figure(figsize=(12, 9))
sns.histplot(gas['gas'], bins=100)
plt.title('Плотность распределения подачи газа')
plt.xlabel('Газ')
plt.ylabel('Частота измерений')
plt.show()

# %%
final_data_temp = temp.groupby('key').agg(['first', 'last']).reset_index()

final_data_temp.columns = ['key', 'first_temp_ts', 'finish_temp_ts', 'first_temp', 'last_temp']
final_data_temp['time_temp_diff'] = final_data_temp['finish_temp_ts'] - final_data_temp['first_temp_ts']
final_data_temp['time_temp_diff'] = final_data_temp['time_temp_diff'].dt.seconds
final_data_temp = final_data_temp.query('key < 2500')
final_data_temp
# Out:
#        key       first_temp_ts      finish_temp_ts  first_temp  last_temp  \
# 0        1 1900-01-01 11:16:18 1900-01-01 11:30:39      1571.0     1613.0
# 1        2 1900-01-01 11:37:27 1900-01-01 11:59:12      1581.0     1602.0
# 2        3 1900-01-01 12:13:17 1900-01-01 12:34:57      1596.0     1599.0
# 3        4 1900-01-01 12:52:57 1900-01-01 12:59:25      1601.0     1625.0
# 4        5 1900-01-01 13:23:19 1900-01-01 13:36:01      1576.0     1602.0
# ...    ...                 ...                 ...         ...        ...
# 2472  2495 1900-01-01 00:35:45 1900-01-01 00:54:42      1570.0     1591.0
# 2473  2496 1900-01-01 01:02:54 1900-01-01 01:29:52      1554.0     1591.0
# 2474  2497 1900-01-01 01:41:53 1900-01-01 01:53:50      1571.0     1589.0
# 2475  2498 1900-01-01 02:03:49 1900-01-01 02:25:31      1591.0     1594.0
# 2476  2499 1900-01-01 02:40:25 1900-01-01 03:00:28      1569.0     1603.0
#
#       time_temp_diff
# 0                861
# 1               1305
# 2               1300
# 3                388
# 4                762
# ...              ...
# 2472            1137
# 2473            1618
# 2474             717
# 2475            1302
# 2476            1203
#
# [2477 rows x 6 columns]

# %%
final_data_temp=final_data_temp.drop(['first_temp_ts', 'finish_temp_ts'],axis=1)

# %%
#temp['rank'] = temp.groupby('key')['MesaureTime'].rank(ascending=False)
#temp[temp['key'].isin([1,2])]

# %%
#temp_asc = temp.copy() 
#temp_asc['rank'] = temp_asc.groupby('key')['MesaureTime'].rank(ascending=True)

#temp_first = temp_asc[temp_asc['rank'] == 1].drop(columns=['MesaureTime', 'rank'])
#temp_first.columns = ['key', 'temp_first']

#temp_last = temp[temp['rank'] == 1].drop(columns=['MesaureTime', 'rank'],axis=1)
#temp_last.columns = ['key', 'temp_last']
#display(temp_first.head(),temp_last.head())

# %%
#temp_df= temp_first.merge(right=temp_last,how='left',on='key')

# %%
#temp_df

# %%
plt.figure(figsize=(10,10))
sns.boxplot(data=final_data_temp.drop(columns=['key','time_temp_diff']), orient="h")
plt.title('Температура нагрева')
plt.xlabel('Градусы')
plt.ylabel('Показатель')

plt.show()

# %%
arc = arc.groupby('key')['FullPower'].sum()
arc= arc.reset_index()

# %%
df_result = pd.DataFrame()

if df_result.empty:
    df_result = merger_by_key_inner(final_data_temp, arc)
    df_result = merger_by_key_inner(df_result, bulk)
    df_result = merger_by_key_inner(df_result, wire)
    df_result = merger_by_key_inner(df_result, gas)
data_analis(df_result)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2329 entries, 0 to 2328
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   key             2329 non-null   int64
#  1   first_temp      2329 non-null   float64
#  2   last_temp       2329 non-null   float64
#  3   time_temp_diff  2329 non-null   int64
#  4   FullPower       2329 non-null   float64
#  5   Bulk 3          2329 non-null   float64
#  6   Bulk 4          2329 non-null   float64
#  7   Bulk 6          2329 non-null   float64
#  8   Bulk 12         2329 non-null   float64
#  9   Bulk 14         2329 non-null   float64
#  10  Bulk 15         2329 non-null   float64
#  11  Wire 1          2329 non-null   float64
#  12  Wire 2          2329 non-null   float64
#  13  gas             2329 non-null   float64
# dtypes: float64(12), int64(2)
# memory usage: 272.9 KB
#    key  first_temp  last_temp  time_temp_diff  FullPower  Bulk 3  Bulk 4  \
# 0    1      1571.0     1613.0             861   5.826395     0.0    43.0
# 1    2      1581.0     1602.0            1305   3.649216     0.0    73.0
# 2    3      1596.0     1599.0            1300   2.989534     0.0    34.0
# 3    4      1601.0     1625.0             388   3.814962     0.0    81.0
# 4    5      1576.0     1602.0             762   4.035758     0.0    78.0
#
#    Bulk 6  Bulk 12  Bulk 14  Bulk 15     Wire 1   Wire 2        gas
# 0     0.0    206.0    150.0    154.0  60.059998  0.00000  29.749986
# 1     0.0    206.0    149.0    154.0  96.052315  0.00000  12.555561
# 2     0.0    205.0    152.0    153.0  91.160157  0.00000  28.554793
# 3     0.0    207.0    153.0    154.0  89.063515  0.00000  18.841219
# 4     0.0    203.0    151.0    152.0  89.238236  9.11456   5.413692
#                key   first_temp    last_temp  time_temp_diff    FullPower  \
# count  2329.000000  2329.000000  2329.000000     2329.000000  2329.000000
# mean   1251.832546  1587.386003  1593.365393     1898.290253     3.941677
# std     714.762400    23.619841    11.200915     1322.054556     1.779518
# min       1.000000  1519.000000  1541.000000      234.000000     0.257637
# 25%     630.000000  1571.000000  1587.000000     1215.000000     2.735080
# 50%    1255.000000  1587.000000  1593.000000     1634.000000     3.773603
# 75%    1868.000000  1603.000000  1598.000000     2290.000000     4.892791
# max    2499.000000  1660.000000  1653.000000    23537.000000    21.564771
#
#             Bulk 3       Bulk 4       Bulk 6      Bulk 12      Bulk 14  \
# count  2329.000000  2329.000000  2329.000000  2329.000000  2329.000000
# mean     47.348218    37.303564    22.430228   208.415629   153.853585
# std      75.310430    58.643238    55.790873   157.062272    81.404354
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000   105.000000   105.000000
# 50%       0.000000     0.000000     0.000000   206.000000   149.000000
# 75%      80.000000    77.000000     0.000000   282.000000   204.000000
# max     454.000000   281.000000   503.000000  1849.000000   636.000000
#
#            Bulk 15       Wire 1       Wire 2          gas
# count  2329.000000  2329.000000  2329.000000  2329.000000
# mean    119.952769   102.443601    17.609859    11.375600
# std      84.640443    43.539993    33.624771     6.392041
# min       0.000000     0.000000     0.000000     0.008399
# 25%       0.000000    73.207679     0.000000     7.282948
# 50%     107.000000   101.119201     0.000000    10.100950
# 75%     204.000000   128.091599    23.102560    14.216688
# max     405.000000   330.314424   282.780152    77.995040
# дубликаты: 0
#                 пропуски  % потерь
# key                    0         0
# first_temp             0         0
# last_temp              0         0
# time_temp_diff         0         0
# FullPower              0         0
# Bulk 3                 0         0
# Bulk 4                 0         0
# Bulk 6                 0         0
# Bulk 12                0         0
# Bulk 14                0         0
# Bulk 15                0         0
# Wire 1                 0         0
# Wire 2                 0         0
# gas                    0         0

# %%
df_result.shape
# Out:
# (2329, 14)

# %%
plt.figure(figsize=(10,10))
sns.boxplot(data=df_result[['first_temp','last_temp']], orient="h")
plt.title('Температура нагрева')
plt.xlabel('Градусы')
plt.ylabel('Показатель')

plt.show()

# %%
plt.figure(figsize=(12, 9))
plt.hist(df_result['time_temp_diff'], bins=100)
plt.title('Плотность распределения подачи времени нагревания')
plt.xlabel('времемя нагревания')
plt.ylabel('Частота измерений')
plt.show()

# %%
df_result=df_result.drop(df_result[df_result['time_temp_diff']>13000].index)

# %%
plt.figure(figsize=(12, 9))
plt.hist(df_result['FullPower'], bins=100)
plt.title('Плотность распределения подачи мощности')
plt.xlabel('мощность')
plt.ylabel('Частота измерений')
plt.show()

# %%
key=df_result.iloc[:,5:11]
plt.figure(figsize=(12,9))
sns.boxplot(data=key,orient="h")
plt.title('количество подаваемой присадки')
plt.xlabel('количество')
plt.ylabel('номер присадки')
plt.grid();

# %%
df_result=df_result.drop(df_result[df_result['Bulk 12']>700].index)

# %%
key=df_result.iloc[:,11:13]
plt.figure(figsize=(12,9))
sns.boxplot(data=key,orient="h")
plt.title('количество подаваемой проволоки')
plt.xlabel('количество')
plt.ylabel('номер проволоки')
plt.grid();

# %%
df_result=df_result.drop(df_result[df_result['Wire 1']>250].index)
df_result=df_result.drop(df_result[df_result['Wire 2']>250].index)

# %%
plt.figure(figsize=(12, 9))
plt.hist(df_result['gas'], bins=100)
plt.title('Плотность распределения подачи газа')
plt.xlabel('Газ')
plt.ylabel('Частота измерений')
plt.show()

# %%
df_result=df_result.drop(df_result[df_result['gas']>41].index)

# %%
df_result.shape
# Out:
# (2314, 14)

# %%
key= df_result.drop('key',axis=1)
plt.figure(figsize=(13, 13),dpi=75)
plt.title('карта корреляций',size=20)
sns.heatmap(key.corr(), annot = True, cmap='seismic');

# %% [markdown]
# <div style="padding: 30px 25px; border: 3px #7AD1FF solid">
#
# <p style="font-weight: bold; text-align: center;"> вывод <p>
#
# - обработали данные
#     - избавились от аномалий
#     - заполнили пропуски 0
#     - удалили лишние стобци в которых % потерь был более 80
#     - создали новые данные по температуре, времени нагрева, потребляеиой мощьности
#     - привели данные со временем в тип timedelta
# - обьединили данные в общюю таблицу
# - создали карту корреляций
# ---
# - видна зависимость температуры и количества подаваемой проволоки под номером 1
# - количество потребляемой мощьности почти на прмямую зависит от времени нагрева
# - есть зависимость между количеством газа и количеством материала под номером 14
# - сильно видна зависимость между количеством материала 12 и 15
# - проволока под номером 1 и количество материала номер 12
# - материал 12 и 14 не ожиданно сильно зависят друг от друга

# %% [markdown]
# # разделение данных на выборки для обучения

# %%
features = df_result.drop(['last_temp', 'key'], axis=1)
target = df_result['last_temp']
print(f'размер features: {features.shape} размер target : {target.shape}')
# Out:
# размер features: (2314, 12) размер target : (2314,)

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2314 entries, 0 to 2328
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   first_temp      2314 non-null   float64
#  1   time_temp_diff  2314 non-null   int64
#  2   FullPower       2314 non-null   float64
#  3   Bulk 3          2314 non-null   float64
#  4   Bulk 4          2314 non-null   float64
#  5   Bulk 6          2314 non-null   float64
#  6   Bulk 12         2314 non-null   float64
#  7   Bulk 14         2314 non-null   float64
#  8   Bulk 15         2314 non-null   float64
#  9   Wire 1          2314 non-null   float64
#  10  Wire 2          2314 non-null   float64
#  11  gas             2314 non-null   float64
# dtypes: float64(11), int64(1)
# memory usage: 235.0 KB

# %%
x_train, x_test, y_train, y_test = train_test_split(features,
                                                            target,
                                                            test_size=0.25,
                                                            random_state=SEED)


print(f'размер features_train: {x_train.shape} размер target_train : {y_train.shape}')
print(f'размер features_test: {x_test.shape} размер target : {y_test.shape}')
# Out:
# размер features_train: (1735, 12) размер target_train : (1735,)
# размер features_test: (579, 12) размер target : (579,)

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test= scaler.transform(x_test)

# %% [markdown]
# <div style="padding: 30px 25px; border: 3px #7AD1FF solid">
# <p style="font-weight: bold; text-align: center;"> вывод <p>
#
# - разделили данные на тренировойчную и тестовую выборки в процентном соотношении 0.25
# - создали отдельную выборку для линейной регресии

# %% [markdown]
# <div style="font-size:30px ;padding: 30px 25px; background-color:#7AD1FF ;solid;font-weight:400">
# <p style="font-weight: bold; text-align: center;"> глава 3. Обучение моделей

# %% [markdown]
# <div style="padding: 30px 25px; border: 3px #7AD1FF solid">
#
# <p style="font-weight: bold; text-align: center;"> LinearRegression

# %%
grid = {'positive': [True]}

model_lr = LinearRegression()

lr_grid = RandomizedSearchCV(estimator=model_lr,
                                      param_distributions=grid,
                                      cv=10,
                                      verbose=5,
                                       scoring = 'neg_mean_absolute_error',
                                      random_state=SEED)

# %%
# %%time
lr_grid.fit(x_train,y_train)
final_metrics_LR = lr_grid.best_score_
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END .................................positive=True; total time=   0.0s
# [CV 2/10] END .................................positive=True; total time=   0.0s
# [CV 3/10] END .................................positive=True; total time=   0.0s
# [CV 4/10] END .................................positive=True; total time=   0.0s
# [CV 5/10] END .................................positive=True; total time=   0.0s
# [CV 6/10] END .................................positive=True; total time=   0.0s
# [CV 7/10] END .................................positive=True; total time=   0.0s
# [CV 8/10] END .................................positive=True; total time=   0.0s
# [CV 9/10] END .................................positive=True; total time=   0.0s
# [CV 10/10] END ................................positive=True; total time=   0.0s
# CPU times: user 170 ms, sys: 0 ns, total: 170 ms
# Wall time: 193 ms

# %%
print(f'MAE:\n{final_metrics_LR}')
# Out:
# MAE:
# -6.623760811535513

# %% [markdown]
# <div style="padding: 30px 25px; border: 3px #7AD1FF solid">
#
# <p style="font-weight: bold; text-align: center;"> Lasso

# %%
grid = {'alpha':[0.1]}

model_lr = Lasso()

lr_lasso_grid = RandomizedSearchCV(estimator=model_lr,
                                      param_distributions=grid,
                                      cv=10,
                                      verbose=5,
                                       scoring = 'neg_mean_absolute_error',
                                      random_state=SEED)

# %%
# %%time
lr_lasso_grid.fit(x_train,y_train)
final_metrics_LR_lasso = lr_lasso_grid.best_score_
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END .....................................alpha=0.1; total time=   0.0s
# [CV 2/10] END .....................................alpha=0.1; total time=   0.0s
# [CV 3/10] END .....................................alpha=0.1; total time=   0.0s
# [CV 4/10] END .....................................alpha=0.1; total time=   0.1s
# [CV 5/10] END .....................................alpha=0.1; total time=   0.0s
# [CV 6/10] END .....................................alpha=0.1; total time=   0.0s
# [CV 7/10] END .....................................alpha=0.1; total time=   0.1s
# [CV 8/10] END .....................................alpha=0.1; total time=   0.0s
# [CV 9/10] END .....................................alpha=0.1; total time=   0.1s
# [CV 10/10] END ....................................alpha=0.1; total time=   0.0s
# CPU times: user 141 ms, sys: 276 ms, total: 417 ms
# Wall time: 430 ms

# %%
print(f'MAE:\n{final_metrics_LR_lasso}')
# Out:
# MAE:
# -5.782740546640697

# %% [markdown]
# <div style="padding: 30px 25px; border: 3px #7AD1FF solid">
#
# <p style="font-weight: bold; text-align: center;"> CatBoost

# %%
grid = {
        'iterations': [100,120,150],
        'learning_rate': [1,0.1,0.01],
        'depth': [2,5,7,10]
       }
model_cat= CatBoostRegressor(loss_function='MAE', eval_metric='MAE')

catboost_grid = RandomizedSearchCV(estimator=model_cat,
                                   param_distributions=grid,
                                      cv=3,
                                  verbose=2,
                                  random_state=SEED)

# %%
# %%time
catboost_grid.fit(x_train,y_train)
best_model_CB = catboost_grid.best_estimator_
final_metrics_CB = best_model_CB.best_score_
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# 0:	learn: 5.2119369	total: 77.2ms	remaining: 11.5s
# 1:	learn: 4.1539784	total: 109ms	remaining: 8.05s
# 2:	learn: 3.9956739	total: 137ms	remaining: 6.72s
# 3:	learn: 3.3737016	total: 162ms	remaining: 5.92s
# 4:	learn: 3.1851203	total: 186ms	remaining: 5.38s
# 5:	learn: 3.0207604	total: 209ms	remaining: 5.01s
# 6:	learn: 2.7430787	total: 233ms	remaining: 4.76s
# 7:	learn: 2.6055356	total: 257ms	remaining: 4.56s
# 8:	learn: 2.5173002	total: 281ms	remaining: 4.4s
# 9:	learn: 2.3209335	total: 308ms	remaining: 4.31s
# 10:	learn: 2.1807951	total: 333ms	remaining: 4.21s
# 11:	learn: 2.0795840	total: 358ms	remaining: 4.12s
# 12:	learn: 1.8390996	total: 382ms	remaining: 4.03s
# 13:	learn: 1.6825251	total: 407ms	remaining: 3.95s
# 14:	learn: 1.5795839	total: 431ms	remaining: 3.88s
# 15:	learn: 1.5320061	total: 455ms	remaining: 3.81s
# 16:	learn: 1.3356393	total: 481ms	remaining: 3.76s
# 17:	learn: 1.3140130	total: 506ms	remaining: 3.71s
# 18:	learn: 1.2301029	total: 531ms	remaining: 3.66s
# 19:	learn: 1.1470579	total: 558ms	remaining: 3.62s
# 20:	learn: 1.0882344	total: 586ms	remaining: 3.6s
# 21:	learn: 1.0112446	total: 618ms	remaining: 3.59s
# 22:	learn: 0.9956737	total: 655ms	remaining: 3.62s
# 23:	learn: 0.9524211	total: 686ms	remaining: 3.6s
# 24:	learn: 0.9013830	total: 716ms	remaining: 3.58s
# 25:	learn: 0.8676460	total: 741ms	remaining: 3.53s
# 26:	learn: 0.8269886	total: 766ms	remaining: 3.49s
# 27:	learn: 0.7240475	total: 792ms	remaining: 3.45s
# 28:	learn: 0.6885804	total: 817ms	remaining: 3.41s
# 29:	learn: 0.6704143	total: 841ms	remaining: 3.36s
# 30:	learn: 0.6133209	total: 865ms	remaining: 3.32s
# 31:	learn: 0.6029402	total: 889ms	remaining: 3.28s
# 32:	learn: 0.5908296	total: 913ms	remaining: 3.24s
# 33:	learn: 0.5605529	total: 937ms	remaining: 3.2s
# 34:	learn: 0.5354665	total: 962ms	remaining: 3.16s
# 35:	learn: 0.5242208	total: 985ms	remaining: 3.12s
# 36:	learn: 0.5181655	total: 1.01s	remaining: 3.09s
# 37:	learn: 0.5103801	total: 1.04s	remaining: 3.06s
# 38:	learn: 0.5034596	total: 1.06s	remaining: 3.02s
# 39:	learn: 0.5025945	total: 1.08s	remaining: 2.98s
# 40:	learn: 0.4939440	total: 1.11s	remaining: 2.95s
# 41:	learn: 0.4922139	total: 1.13s	remaining: 2.92s
# 42:	learn: 0.4757779	total: 1.16s	remaining: 2.88s
# 43:	learn: 0.4359856	total: 1.18s	remaining: 2.85s
# 44:	learn: 0.4065738	total: 1.21s	remaining: 2.81s
# 45:	learn: 0.4048437	total: 1.23s	remaining: 2.78s
# 46:	learn: 0.3884077	total: 1.26s	remaining: 2.75s
# 47:	learn: 0.3745669	total: 1.28s	remaining: 2.72s
# 48:	learn: 0.3416951	total: 1.31s	remaining: 2.71s
# 49:	learn: 0.3416951	total: 1.34s	remaining: 2.69s
# 50:	learn: 0.3347747	total: 1.37s	remaining: 2.66s
# 51:	learn: 0.3330446	total: 1.4s	remaining: 2.63s
# 52:	learn: 0.3295844	total: 1.42s	remaining: 2.6s
# 53:	learn: 0.3166086	total: 1.45s	remaining: 2.57s
# 54:	learn: 0.3036329	total: 1.47s	remaining: 2.54s
# 55:	learn: 0.2984426	total: 1.5s	remaining: 2.51s
# 56:	learn: 0.2975774	total: 1.52s	remaining: 2.48s
# 57:	learn: 0.2975774	total: 1.55s	remaining: 2.46s
# 58:	learn: 0.2967124	total: 1.58s	remaining: 2.43s
# 59:	learn: 0.2967124	total: 1.6s	remaining: 2.4s
# 60:	learn: 0.2915221	total: 1.63s	remaining: 2.38s
# 61:	learn: 0.2854667	total: 1.65s	remaining: 2.35s
# 62:	learn: 0.2854667	total: 1.68s	remaining: 2.31s
# 63:	learn: 0.2802764	total: 1.7s	remaining: 2.29s
# 64:	learn: 0.2742211	total: 1.73s	remaining: 2.26s
# 65:	learn: 0.2742211	total: 1.75s	remaining: 2.23s
# 66:	learn: 0.2681657	total: 1.78s	remaining: 2.2s
# 67:	learn: 0.2681656	total: 1.8s	remaining: 2.17s
# 68:	learn: 0.2673005	total: 1.82s	remaining: 2.14s
# 69:	learn: 0.2673005	total: 1.84s	remaining: 2.11s
# 70:	learn: 0.2673005	total: 1.86s	remaining: 2.08s
# 71:	learn: 0.2586501	total: 1.89s	remaining: 2.04s
# 72:	learn: 0.2560550	total: 1.91s	remaining: 2.02s
# 73:	learn: 0.2560550	total: 1.93s	remaining: 1.99s
# 74:	learn: 0.2534598	total: 1.96s	remaining: 1.96s
# 75:	learn: 0.2413491	total: 1.98s	remaining: 1.93s
# 76:	learn: 0.2413491	total: 2s	remaining: 1.9s
# 77:	learn: 0.2257781	total: 2.02s	remaining: 1.87s
# 78:	learn: 0.2240480	total: 2.05s	remaining: 1.84s
# 79:	learn: 0.2240481	total: 2.07s	remaining: 1.81s
# 80:	learn: 0.2240481	total: 2.09s	remaining: 1.78s
# 81:	learn: 0.2188578	total: 2.12s	remaining: 1.75s
# 82:	learn: 0.2188577	total: 2.14s	remaining: 1.73s
# 83:	learn: 0.2188577	total: 2.17s	remaining: 1.7s
# 84:	learn: 0.2188578	total: 2.19s	remaining: 1.68s
# 85:	learn: 0.2153976	total: 2.22s	remaining: 1.65s
# 86:	learn: 0.2153976	total: 2.24s	remaining: 1.62s
# 87:	learn: 0.2145326	total: 2.26s	remaining: 1.59s
# 88:	learn: 0.2145325	total: 2.29s	remaining: 1.57s
# 89:	learn: 0.2145325	total: 2.31s	remaining: 1.54s
# 90:	learn: 0.2110723	total: 2.35s	remaining: 1.52s
# 91:	learn: 0.2110723	total: 2.37s	remaining: 1.49s
# 92:	learn: 0.2076121	total: 2.39s	remaining: 1.47s
# 93:	learn: 0.2050169	total: 2.42s	remaining: 1.44s
# 94:	learn: 0.2050168	total: 2.45s	remaining: 1.42s
# 95:	learn: 0.1946362	total: 2.47s	remaining: 1.39s
# 96:	learn: 0.1946362	total: 2.5s	remaining: 1.36s
# 97:	learn: 0.1937712	total: 2.52s	remaining: 1.34s
# 98:	learn: 0.1885810	total: 2.55s	remaining: 1.31s
# 99:	learn: 0.1885810	total: 2.58s	remaining: 1.29s
# 100:	learn: 0.1868509	total: 2.6s	remaining: 1.26s
# 101:	learn: 0.1868509	total: 2.63s	remaining: 1.24s
# 102:	learn: 0.1807955	total: 2.65s	remaining: 1.21s
# 103:	learn: 0.1790654	total: 2.67s	remaining: 1.18s
# 104:	learn: 0.1730100	total: 2.7s	remaining: 1.16s
# 105:	learn: 0.1730100	total: 2.72s	remaining: 1.13s
# 106:	learn: 0.1730100	total: 2.74s	remaining: 1.1s
# 107:	learn: 0.1695499	total: 2.77s	remaining: 1.08s
# 108:	learn: 0.1669548	total: 2.79s	remaining: 1.05s
# 109:	learn: 0.1531141	total: 2.82s	remaining: 1.02s
# 110:	learn: 0.1513839	total: 2.85s	remaining: 1000ms
# 111:	learn: 0.1513839	total: 2.87s	remaining: 974ms
# 112:	learn: 0.1461936	total: 2.9s	remaining: 948ms
# 113:	learn: 0.1384084	total: 2.92s	remaining: 922ms
# 114:	learn: 0.1262976	total: 2.95s	remaining: 897ms
# 115:	learn: 0.1262976	total: 2.98s	remaining: 873ms
# 116:	learn: 0.1262976	total: 3s	remaining: 847ms
# 117:	learn: 0.1211074	total: 3.03s	remaining: 821ms
# 118:	learn: 0.1211073	total: 3.06s	remaining: 796ms
# 119:	learn: 0.1211074	total: 3.08s	remaining: 770ms
# 120:	learn: 0.1211074	total: 3.11s	remaining: 745ms
# 121:	learn: 0.1211073	total: 3.13s	remaining: 719ms
# 122:	learn: 0.1211073	total: 3.16s	remaining: 694ms
# 123:	learn: 0.1211075	total: 3.18s	remaining: 668ms
# 124:	learn: 0.1211075	total: 3.21s	remaining: 642ms
# 125:	learn: 0.1211074	total: 3.24s	remaining: 617ms
# 126:	learn: 0.1211073	total: 3.26s	remaining: 591ms
# 127:	learn: 0.1133219	total: 3.29s	remaining: 566ms
# 128:	learn: 0.1107267	total: 3.31s	remaining: 540ms
# 129:	learn: 0.1107267	total: 3.34s	remaining: 514ms
# 130:	learn: 0.1107267	total: 3.36s	remaining: 488ms
# 131:	learn: 0.1029413	total: 3.39s	remaining: 462ms
# 132:	learn: 0.1029413	total: 3.41s	remaining: 436ms
# 133:	learn: 0.1029413	total: 3.44s	remaining: 410ms
# 134:	learn: 0.1012112	total: 3.46s	remaining: 385ms
# 135:	learn: 0.1012112	total: 3.48s	remaining: 359ms
# 136:	learn: 0.1012112	total: 3.51s	remaining: 333ms
# 137:	learn: 0.1012112	total: 3.54s	remaining: 307ms
# 138:	learn: 0.1012111	total: 3.56s	remaining: 282ms
# 139:	learn: 0.1012111	total: 3.58s	remaining: 256ms
# 140:	learn: 0.1012112	total: 3.61s	remaining: 230ms
# 141:	learn: 0.0968859	total: 3.64s	remaining: 205ms
# 142:	learn: 0.0830450	total: 3.67s	remaining: 180ms
# 143:	learn: 0.0830450	total: 3.7s	remaining: 154ms
# 144:	learn: 0.0830450	total: 3.72s	remaining: 128ms
# 145:	learn: 0.0830450	total: 3.75s	remaining: 103ms
# 146:	learn: 0.0830450	total: 3.77s	remaining: 77ms
# 147:	learn: 0.0830450	total: 3.8s	remaining: 51.3ms
# 148:	learn: 0.0830450	total: 3.82s	remaining: 25.6ms
# 149:	learn: 0.0830450	total: 3.85s	remaining: 0us
# [CV] END ..........depth=10, iterations=150, learning_rate=1; total time=   4.4s
# 0:	learn: 5.4209154	total: 22.8ms	remaining: 3.39s
# 1:	learn: 4.4105437	total: 45.4ms	remaining: 3.36s
# 2:	learn: 3.8755393	total: 68.5ms	remaining: 3.35s
# 3:	learn: 3.5592040	total: 91.3ms	remaining: 3.33s
# 4:	learn: 3.2273112	total: 115ms	remaining: 3.34s
# 5:	learn: 2.9714771	total: 139ms	remaining: 3.33s
# 6:	learn: 2.8452887	total: 163ms	remaining: 3.33s
# 7:	learn: 2.5834045	total: 188ms	remaining: 3.34s
# 8:	learn: 2.3362134	total: 214ms	remaining: 3.35s
# 9:	learn: 2.2152108	total: 242ms	remaining: 3.38s
# 10:	learn: 2.0838365	total: 265ms	remaining: 3.35s
# 11:	learn: 1.9524622	total: 290ms	remaining: 3.33s
# 12:	learn: 1.8591173	total: 313ms	remaining: 3.3s
# 13:	learn: 1.7796013	total: 336ms	remaining: 3.26s
# 14:	learn: 1.7372504	total: 358ms	remaining: 3.22s
# 15:	learn: 1.6274836	total: 381ms	remaining: 3.19s
# 16:	learn: 1.4883307	total: 404ms	remaining: 3.16s
# 17:	learn: 1.3906644	total: 429ms	remaining: 3.15s
# 18:	learn: 1.2981839	total: 453ms	remaining: 3.12s
# 19:	learn: 1.2212609	total: 476ms	remaining: 3.1s
# 20:	learn: 1.1711312	total: 500ms	remaining: 3.07s
# 21:	learn: 1.1210016	total: 525ms	remaining: 3.06s
# 22:	learn: 1.0847008	total: 556ms	remaining: 3.07s
# 23:	learn: 1.0293854	total: 580ms	remaining: 3.05s
# 24:	learn: 1.0112351	total: 606ms	remaining: 3.03s
# 25:	learn: 0.9524624	total: 633ms	remaining: 3.02s
# 26:	learn: 0.9144330	total: 666ms	remaining: 3.03s
# 27:	learn: 0.8141738	total: 692ms	remaining: 3.02s
# 28:	learn: 0.7986164	total: 715ms	remaining: 2.98s
# 29:	learn: 0.7882448	total: 739ms	remaining: 2.96s
# 30:	learn: 0.7337936	total: 763ms	remaining: 2.93s
# 31:	learn: 0.7078645	total: 786ms	remaining: 2.9s
# 32:	learn: 0.7035430	total: 810ms	remaining: 2.87s
# 33:	learn: 0.6923071	total: 834ms	remaining: 2.84s
# 34:	learn: 0.6862570	total: 859ms	remaining: 2.82s
# 35:	learn: 0.6516848	total: 882ms	remaining: 2.79s
# 36:	learn: 0.6343988	total: 907ms	remaining: 2.77s
# 37:	learn: 0.6240271	total: 932ms	remaining: 2.75s
# 38:	learn: 0.6222985	total: 956ms	remaining: 2.72s
# 39:	learn: 0.6127911	total: 981ms	remaining: 2.7s
# 40:	learn: 0.6127911	total: 1s	remaining: 2.67s
# 41:	learn: 0.5669831	total: 1.03s	remaining: 2.64s
# 42:	learn: 0.5626617	total: 1.05s	remaining: 2.61s
# 43:	learn: 0.5393254	total: 1.07s	remaining: 2.58s
# 44:	learn: 0.5324110	total: 1.1s	remaining: 2.56s
# 45:	learn: 0.5254965	total: 1.12s	remaining: 2.54s
# 46:	learn: 0.5194463	total: 1.15s	remaining: 2.51s
# 47:	learn: 0.5185821	total: 1.17s	remaining: 2.48s
# 48:	learn: 0.4909244	total: 1.19s	remaining: 2.46s
# 49:	learn: 0.4831457	total: 1.22s	remaining: 2.44s
# 50:	learn: 0.4831457	total: 1.24s	remaining: 2.41s
# 51:	learn: 0.4805527	total: 1.27s	remaining: 2.39s
# 52:	learn: 0.4131369	total: 1.29s	remaining: 2.36s
# 53:	learn: 0.4010367	total: 1.32s	remaining: 2.35s
# 54:	learn: 0.4010368	total: 1.34s	remaining: 2.32s
# 55:	learn: 0.3915294	total: 1.37s	remaining: 2.29s
# 56:	learn: 0.3846150	total: 1.39s	remaining: 2.27s
# 57:	learn: 0.3846150	total: 1.42s	remaining: 2.25s
# 58:	learn: 0.3811577	total: 1.44s	remaining: 2.22s
# 59:	learn: 0.3777005	total: 1.46s	remaining: 2.19s
# 60:	learn: 0.3777005	total: 1.49s	remaining: 2.17s
# 61:	learn: 0.3725146	total: 1.51s	remaining: 2.14s
# 62:	learn: 0.3673288	total: 1.53s	remaining: 2.12s
# 63:	learn: 0.3578214	total: 1.56s	remaining: 2.09s
# 64:	learn: 0.3569572	total: 1.58s	remaining: 2.07s
# 65:	learn: 0.3569572	total: 1.61s	remaining: 2.04s
# 66:	learn: 0.3431283	total: 1.63s	remaining: 2.02s
# 67:	learn: 0.3422639	total: 1.65s	remaining: 2s
# 68:	learn: 0.3344852	total: 1.68s	remaining: 1.97s
# 69:	learn: 0.3336209	total: 1.7s	remaining: 1.94s
# 70:	learn: 0.3120133	total: 1.73s	remaining: 1.92s
# 71:	learn: 0.3042346	total: 1.76s	remaining: 1.9s
# 72:	learn: 0.2947272	total: 1.78s	remaining: 1.88s
# 73:	learn: 0.2938628	total: 1.81s	remaining: 1.86s
# 74:	learn: 0.2921343	total: 1.83s	remaining: 1.83s
# 75:	learn: 0.2895413	total: 1.85s	remaining: 1.81s
# 76:	learn: 0.2748482	total: 1.88s	remaining: 1.78s
# 77:	learn: 0.2662052	total: 1.9s	remaining: 1.75s
# 78:	learn: 0.2662052	total: 1.92s	remaining: 1.73s
# 79:	learn: 0.2618837	total: 1.95s	remaining: 1.7s
# 80:	learn: 0.2437333	total: 1.97s	remaining: 1.68s
# 81:	learn: 0.2437333	total: 2s	remaining: 1.65s
# 82:	learn: 0.2428690	total: 2.02s	remaining: 1.63s
# 83:	learn: 0.2428690	total: 2.04s	remaining: 1.6s
# 84:	learn: 0.2368188	total: 2.06s	remaining: 1.58s
# 85:	learn: 0.2273115	total: 2.09s	remaining: 1.55s
# 86:	learn: 0.2273115	total: 2.11s	remaining: 1.53s
# 87:	learn: 0.2273115	total: 2.13s	remaining: 1.5s
# 88:	learn: 0.2195328	total: 2.16s	remaining: 1.48s
# 89:	learn: 0.2195328	total: 2.18s	remaining: 1.46s
# 90:	learn: 0.2195328	total: 2.22s	remaining: 1.44s
# 91:	learn: 0.2195328	total: 2.24s	remaining: 1.41s
# 92:	learn: 0.2195327	total: 2.27s	remaining: 1.39s
# 93:	learn: 0.2169399	total: 2.29s	remaining: 1.36s
# 94:	learn: 0.2169399	total: 2.31s	remaining: 1.34s
# 95:	learn: 0.2169398	total: 2.34s	remaining: 1.32s
# 96:	learn: 0.2169398	total: 2.37s	remaining: 1.29s
# 97:	learn: 0.2117540	total: 2.39s	remaining: 1.27s
# 98:	learn: 0.2117540	total: 2.41s	remaining: 1.24s
# 99:	learn: 0.2048397	total: 2.43s	remaining: 1.22s
# 100:	learn: 0.2005182	total: 2.46s	remaining: 1.19s
# 101:	learn: 0.2005182	total: 2.48s	remaining: 1.17s
# 102:	learn: 0.1987896	total: 2.5s	remaining: 1.14s
# 103:	learn: 0.1979254	total: 2.52s	remaining: 1.12s
# 104:	learn: 0.1979253	total: 2.55s	remaining: 1.09s
# 105:	learn: 0.1961968	total: 2.57s	remaining: 1.07s
# 106:	learn: 0.1866893	total: 2.6s	remaining: 1.04s
# 107:	learn: 0.1866894	total: 2.62s	remaining: 1.02s
# 108:	learn: 0.1866893	total: 2.65s	remaining: 999ms
# 109:	learn: 0.1840964	total: 2.68s	remaining: 975ms
# 110:	learn: 0.1840964	total: 2.71s	remaining: 951ms
# 111:	learn: 0.1780462	total: 2.73s	remaining: 927ms
# 112:	learn: 0.1780463	total: 2.76s	remaining: 904ms
# 113:	learn: 0.1780463	total: 2.79s	remaining: 881ms
# 114:	learn: 0.1763177	total: 2.82s	remaining: 857ms
# 115:	learn: 0.1763177	total: 2.85s	remaining: 834ms
# 116:	learn: 0.1763178	total: 2.87s	remaining: 810ms
# 117:	learn: 0.1763177	total: 2.9s	remaining: 786ms
# 118:	learn: 0.1763177	total: 2.92s	remaining: 762ms
# 119:	learn: 0.1763177	total: 2.95s	remaining: 738ms
# 120:	learn: 0.1694033	total: 2.99s	remaining: 716ms
# 121:	learn: 0.1694034	total: 3.01s	remaining: 692ms
# 122:	learn: 0.1659462	total: 3.04s	remaining: 667ms
# 123:	learn: 0.1659461	total: 3.07s	remaining: 643ms
# 124:	learn: 0.1598960	total: 3.09s	remaining: 618ms
# 125:	learn: 0.1598960	total: 3.12s	remaining: 594ms
# 126:	learn: 0.1598960	total: 3.14s	remaining: 569ms
# 127:	learn: 0.1391528	total: 3.16s	remaining: 544ms
# 128:	learn: 0.1391528	total: 3.19s	remaining: 519ms
# 129:	learn: 0.1339670	total: 3.21s	remaining: 495ms
# 130:	learn: 0.1339670	total: 3.24s	remaining: 470ms
# 131:	learn: 0.1339670	total: 3.27s	remaining: 445ms
# 132:	learn: 0.1339669	total: 3.29s	remaining: 421ms
# 133:	learn: 0.1339670	total: 3.32s	remaining: 396ms
# 134:	learn: 0.1339670	total: 3.34s	remaining: 371ms
# 135:	learn: 0.1313740	total: 3.37s	remaining: 347ms
# 136:	learn: 0.1261882	total: 3.39s	remaining: 322ms
# 137:	learn: 0.1244596	total: 3.42s	remaining: 297ms
# 138:	learn: 0.1244597	total: 3.44s	remaining: 272ms
# 139:	learn: 0.1244597	total: 3.46s	remaining: 248ms
# 140:	learn: 0.1244596	total: 3.49s	remaining: 223ms
# 141:	learn: 0.1244597	total: 3.52s	remaining: 198ms
# 142:	learn: 0.1244596	total: 3.54s	remaining: 173ms
# 143:	learn: 0.1244597	total: 3.56s	remaining: 149ms
# 144:	learn: 0.1244597	total: 3.59s	remaining: 124ms
# 145:	learn: 0.1244597	total: 3.61s	remaining: 99ms
# 146:	learn: 0.1244597	total: 3.64s	remaining: 74.3ms
# 147:	learn: 0.1244596	total: 3.66s	remaining: 49.5ms
# 148:	learn: 0.1244597	total: 3.69s	remaining: 24.7ms
# 149:	learn: 0.1244597	total: 3.71s	remaining: 0us
# [CV] END ..........depth=10, iterations=150, learning_rate=1; total time=   4.2s
# 0:	learn: 6.0069136	total: 25.3ms	remaining: 3.77s
# 1:	learn: 5.0103708	total: 51.8ms	remaining: 3.83s
# 2:	learn: 4.5669827	total: 75.4ms	remaining: 3.69s
# 3:	learn: 4.1555738	total: 98ms	remaining: 3.58s
# 4:	learn: 3.6793422	total: 120ms	remaining: 3.49s
# 5:	learn: 3.2843552	total: 143ms	remaining: 3.43s
# 6:	learn: 3.0043206	total: 165ms	remaining: 3.37s
# 7:	learn: 2.8643033	total: 188ms	remaining: 3.33s
# 8:	learn: 2.4736378	total: 211ms	remaining: 3.3s
# 9:	learn: 2.2549689	total: 235ms	remaining: 3.28s
# 10:	learn: 2.1434737	total: 258ms	remaining: 3.26s
# 11:	learn: 2.0043205	total: 282ms	remaining: 3.24s
# 12:	learn: 1.9567838	total: 304ms	remaining: 3.2s
# 13:	learn: 1.8530673	total: 326ms	remaining: 3.17s
# 14:	learn: 1.7951589	total: 349ms	remaining: 3.14s
# 15:	learn: 1.7199643	total: 373ms	remaining: 3.12s
# 16:	learn: 1.6084691	total: 396ms	remaining: 3.1s
# 17:	learn: 1.5004310	total: 421ms	remaining: 3.09s
# 18:	learn: 1.4364726	total: 448ms	remaining: 3.09s
# 19:	learn: 1.3759713	total: 472ms	remaining: 3.06s
# 20:	learn: 1.2100249	total: 497ms	remaining: 3.05s
# 21:	learn: 1.1875529	total: 520ms	remaining: 3.02s
# 22:	learn: 1.1486593	total: 545ms	remaining: 3.01s
# 23:	learn: 1.0190137	total: 568ms	remaining: 2.98s
# 24:	learn: 0.8530673	total: 591ms	remaining: 2.95s
# 25:	learn: 0.7528081	total: 613ms	remaining: 2.92s
# 26:	learn: 0.6983568	total: 636ms	remaining: 2.9s
# 27:	learn: 0.6439057	total: 658ms	remaining: 2.87s
# 28:	learn: 0.6032836	total: 681ms	remaining: 2.84s
# 29:	learn: 0.5229034	total: 707ms	remaining: 2.83s
# 30:	learn: 0.5133961	total: 730ms	remaining: 2.8s
# 31:	learn: 0.4961101	total: 754ms	remaining: 2.78s
# 32:	learn: 0.4891957	total: 777ms	remaining: 2.75s
# 33:	learn: 0.4243729	total: 800ms	remaining: 2.73s
# 34:	learn: 0.4062225	total: 824ms	remaining: 2.71s
# 35:	learn: 0.3759719	total: 847ms	remaining: 2.68s
# 36:	learn: 0.3638716	total: 871ms	remaining: 2.66s
# 37:	learn: 0.3500427	total: 894ms	remaining: 2.63s
# 38:	learn: 0.3388068	total: 918ms	remaining: 2.61s
# 39:	learn: 0.3379425	total: 942ms	remaining: 2.59s
# 40:	learn: 0.3327567	total: 966ms	remaining: 2.57s
# 41:	learn: 0.3318924	total: 989ms	remaining: 2.54s
# 42:	learn: 0.3284352	total: 1.01s	remaining: 2.52s
# 43:	learn: 0.3249780	total: 1.03s	remaining: 2.49s
# 44:	learn: 0.3180636	total: 1.06s	remaining: 2.47s
# 45:	learn: 0.2800342	total: 1.08s	remaining: 2.44s
# 46:	learn: 0.2791699	total: 1.1s	remaining: 2.42s
# 47:	learn: 0.2791699	total: 1.13s	remaining: 2.4s
# 48:	learn: 0.2731197	total: 1.15s	remaining: 2.37s
# 49:	learn: 0.2713912	total: 1.18s	remaining: 2.36s
# 50:	learn: 0.2705268	total: 1.21s	remaining: 2.36s
# 51:	learn: 0.2696625	total: 1.24s	remaining: 2.33s
# 52:	learn: 0.2696625	total: 1.26s	remaining: 2.31s
# 53:	learn: 0.2696624	total: 1.28s	remaining: 2.28s
# 54:	learn: 0.2584265	total: 1.31s	remaining: 2.26s
# 55:	learn: 0.2566979	total: 1.33s	remaining: 2.23s
# 56:	learn: 0.2497835	total: 1.35s	remaining: 2.2s
# 57:	learn: 0.2497835	total: 1.37s	remaining: 2.18s
# 58:	learn: 0.2480549	total: 1.4s	remaining: 2.15s
# 59:	learn: 0.2480549	total: 1.42s	remaining: 2.13s
# 60:	learn: 0.2359546	total: 1.44s	remaining: 2.1s
# 61:	learn: 0.2299045	total: 1.46s	remaining: 2.08s
# 62:	learn: 0.2299045	total: 1.49s	remaining: 2.05s
# 63:	learn: 0.2299044	total: 1.51s	remaining: 2.03s
# 64:	learn: 0.2290402	total: 1.53s	remaining: 2s
# 65:	learn: 0.2273115	total: 1.55s	remaining: 1.98s
# 66:	learn: 0.2247186	total: 1.57s	remaining: 1.95s
# 67:	learn: 0.2238543	total: 1.6s	remaining: 1.93s
# 68:	learn: 0.2178042	total: 1.62s	remaining: 1.9s
# 69:	learn: 0.2178042	total: 1.64s	remaining: 1.88s
# 70:	learn: 0.2178041	total: 1.67s	remaining: 1.85s
# 71:	learn: 0.2178042	total: 1.69s	remaining: 1.83s
# 72:	learn: 0.2134827	total: 1.71s	remaining: 1.81s
# 73:	learn: 0.2117541	total: 1.74s	remaining: 1.78s
# 74:	learn: 0.2117540	total: 1.76s	remaining: 1.76s
# 75:	learn: 0.2117540	total: 1.78s	remaining: 1.73s
# 76:	learn: 0.2117540	total: 1.8s	remaining: 1.71s
# 77:	learn: 0.2100253	total: 1.82s	remaining: 1.68s
# 78:	learn: 0.2091611	total: 1.85s	remaining: 1.66s
# 79:	learn: 0.2082968	total: 1.87s	remaining: 1.64s
# 80:	learn: 0.2031109	total: 1.9s	remaining: 1.61s
# 81:	learn: 0.1987894	total: 1.92s	remaining: 1.59s
# 82:	learn: 0.1987894	total: 1.95s	remaining: 1.57s
# 83:	learn: 0.1987893	total: 1.97s	remaining: 1.55s
# 84:	learn: 0.1987893	total: 2s	remaining: 1.53s
# 85:	learn: 0.1987893	total: 2.02s	remaining: 1.5s
# 86:	learn: 0.1840962	total: 2.04s	remaining: 1.48s
# 87:	learn: 0.1840962	total: 2.07s	remaining: 1.46s
# 88:	learn: 0.1840962	total: 2.09s	remaining: 1.43s
# 89:	learn: 0.1823676	total: 2.12s	remaining: 1.41s
# 90:	learn: 0.1789104	total: 2.14s	remaining: 1.39s
# 91:	learn: 0.1789104	total: 2.17s	remaining: 1.36s
# 92:	learn: 0.1789104	total: 2.19s	remaining: 1.34s
# 93:	learn: 0.1789104	total: 2.21s	remaining: 1.32s
# 94:	learn: 0.1685388	total: 2.24s	remaining: 1.29s
# 95:	learn: 0.1676745	total: 2.26s	remaining: 1.27s
# 96:	learn: 0.1650817	total: 2.29s	remaining: 1.25s
# 97:	learn: 0.1650817	total: 2.31s	remaining: 1.23s
# 98:	learn: 0.1598959	total: 2.34s	remaining: 1.21s
# 99:	learn: 0.1598958	total: 2.37s	remaining: 1.18s
# 100:	learn: 0.1598959	total: 2.4s	remaining: 1.16s
# 101:	learn: 0.1581673	total: 2.42s	remaining: 1.14s
# 102:	learn: 0.1581672	total: 2.45s	remaining: 1.12s
# 103:	learn: 0.1581672	total: 2.48s	remaining: 1.09s
# 104:	learn: 0.1564386	total: 2.5s	remaining: 1.07s
# 105:	learn: 0.1555744	total: 2.52s	remaining: 1.05s
# 106:	learn: 0.1555744	total: 2.54s	remaining: 1.02s
# 107:	learn: 0.1512529	total: 2.57s	remaining: 999ms
# 108:	learn: 0.1452028	total: 2.59s	remaining: 976ms
# 109:	learn: 0.1452028	total: 2.62s	remaining: 952ms
# 110:	learn: 0.1452028	total: 2.64s	remaining: 928ms
# 111:	learn: 0.1452028	total: 2.67s	remaining: 904ms
# 112:	learn: 0.1452027	total: 2.69s	remaining: 881ms
# 113:	learn: 0.1452027	total: 2.71s	remaining: 856ms
# 114:	learn: 0.1452027	total: 2.73s	remaining: 833ms
# 115:	learn: 0.1452026	total: 2.76s	remaining: 809ms
# 116:	learn: 0.1452026	total: 2.78s	remaining: 785ms
# 117:	learn: 0.1434741	total: 2.81s	remaining: 761ms
# 118:	learn: 0.1434741	total: 2.83s	remaining: 738ms
# 119:	learn: 0.1365596	total: 2.86s	remaining: 715ms
# 120:	learn: 0.1365596	total: 2.88s	remaining: 691ms
# 121:	learn: 0.1365596	total: 2.9s	remaining: 666ms
# 122:	learn: 0.1365596	total: 2.93s	remaining: 643ms
# 123:	learn: 0.1365596	total: 2.95s	remaining: 619ms
# 124:	learn: 0.1365597	total: 2.97s	remaining: 595ms
# 125:	learn: 0.1348310	total: 3s	remaining: 571ms
# 126:	learn: 0.1348310	total: 3.03s	remaining: 548ms
# 127:	learn: 0.1331023	total: 3.05s	remaining: 525ms
# 128:	learn: 0.1322380	total: 3.08s	remaining: 501ms
# 129:	learn: 0.1322379	total: 3.1s	remaining: 477ms
# 130:	learn: 0.1322379	total: 3.13s	remaining: 454ms
# 131:	learn: 0.1322379	total: 3.15s	remaining: 430ms
# 132:	learn: 0.1270520	total: 3.18s	remaining: 406ms
# 133:	learn: 0.1270521	total: 3.2s	remaining: 382ms
# 134:	learn: 0.1140876	total: 3.22s	remaining: 358ms
# 135:	learn: 0.1140875	total: 3.25s	remaining: 334ms
# 136:	learn: 0.1140875	total: 3.27s	remaining: 311ms
# 137:	learn: 0.1063088	total: 3.3s	remaining: 287ms
# 138:	learn: 0.1054445	total: 3.32s	remaining: 263ms
# 139:	learn: 0.1019873	total: 3.35s	remaining: 239ms
# 140:	learn: 0.1019873	total: 3.37s	remaining: 215ms
# 141:	learn: 0.0985302	total: 3.4s	remaining: 191ms
# 142:	learn: 0.0985302	total: 3.42s	remaining: 168ms
# 143:	learn: 0.0950730	total: 3.45s	remaining: 144ms
# 144:	learn: 0.0795156	total: 3.47s	remaining: 120ms
# 145:	learn: 0.0795156	total: 3.5s	remaining: 95.9ms
# 146:	learn: 0.0743298	total: 3.52s	remaining: 71.9ms
# 147:	learn: 0.0743297	total: 3.55s	remaining: 48ms
# 148:	learn: 0.0743297	total: 3.58s	remaining: 24ms
# 149:	learn: 0.0743297	total: 3.6s	remaining: 0us
# [CV] END ..........depth=10, iterations=150, learning_rate=1; total time=   4.1s
# 0:	learn: 7.7103797	total: 694us	remaining: 103ms
# 1:	learn: 7.6338831	total: 1.35ms	remaining: 99.9ms
# 2:	learn: 7.5590699	total: 1.95ms	remaining: 95.4ms
# 3:	learn: 7.5088846	total: 2.48ms	remaining: 90.4ms
# 4:	learn: 7.4344167	total: 2.99ms	remaining: 86.7ms
# 5:	learn: 7.3856537	total: 3.56ms	remaining: 85.4ms
# 6:	learn: 7.3378443	total: 4.48ms	remaining: 91.6ms
# 7:	learn: 7.2655370	total: 5.11ms	remaining: 90.7ms
# 8:	learn: 7.2201873	total: 5.62ms	remaining: 88.1ms
# 9:	learn: 7.1791747	total: 6.18ms	remaining: 86.6ms
# 10:	learn: 7.1479635	total: 6.79ms	remaining: 85.8ms
# 11:	learn: 7.1129714	total: 7.36ms	remaining: 84.6ms
# 12:	learn: 7.0786491	total: 7.91ms	remaining: 83.3ms
# 13:	learn: 7.0471962	total: 8.45ms	remaining: 82ms
# 14:	learn: 6.9553508	total: 9.01ms	remaining: 81.1ms
# 15:	learn: 6.8771590	total: 9.66ms	remaining: 80.9ms
# 16:	learn: 6.8361578	total: 10.3ms	remaining: 80.2ms
# 17:	learn: 6.8089079	total: 10.8ms	remaining: 78.9ms
# 18:	learn: 6.7967275	total: 11.3ms	remaining: 77.9ms
# 19:	learn: 6.7792328	total: 11.8ms	remaining: 76.7ms
# 20:	learn: 6.7506426	total: 12.3ms	remaining: 75.7ms
# 21:	learn: 6.7047756	total: 12.8ms	remaining: 74.7ms
# 22:	learn: 6.6910167	total: 13.3ms	remaining: 73.6ms
# 23:	learn: 6.6664325	total: 13.9ms	remaining: 72.7ms
# 24:	learn: 6.6417796	total: 14.3ms	remaining: 71.7ms
# 25:	learn: 6.5890216	total: 14.9ms	remaining: 70.9ms
# 26:	learn: 6.5629007	total: 15.4ms	remaining: 70.3ms
# 27:	learn: 6.5495676	total: 15.9ms	remaining: 69.4ms
# 28:	learn: 6.5122687	total: 16.4ms	remaining: 68.6ms
# 29:	learn: 6.4822187	total: 17ms	remaining: 68.2ms
# 30:	learn: 6.4666145	total: 17.6ms	remaining: 67.5ms
# 31:	learn: 6.4529148	total: 18.1ms	remaining: 66.7ms
# 32:	learn: 6.4384723	total: 18.6ms	remaining: 65.8ms
# 33:	learn: 6.4228219	total: 19.1ms	remaining: 65.2ms
# 34:	learn: 6.3991820	total: 19.6ms	remaining: 64.5ms
# 35:	learn: 6.3830705	total: 20.2ms	remaining: 63.9ms
# 36:	learn: 6.3663968	total: 20.7ms	remaining: 63.2ms
# 37:	learn: 6.3485429	total: 21.3ms	remaining: 62.7ms
# 38:	learn: 6.3292791	total: 21.8ms	remaining: 62ms
# 39:	learn: 6.3054600	total: 22.3ms	remaining: 61.4ms
# 40:	learn: 6.3008580	total: 22.8ms	remaining: 60.7ms
# 41:	learn: 6.2846738	total: 23.3ms	remaining: 60ms
# 42:	learn: 6.2712022	total: 23.9ms	remaining: 59.4ms
# 43:	learn: 6.2476254	total: 24.5ms	remaining: 58.9ms
# 44:	learn: 6.2371599	total: 25ms	remaining: 58.4ms
# 45:	learn: 6.2059763	total: 25.6ms	remaining: 57.9ms
# 46:	learn: 6.1800415	total: 26.1ms	remaining: 57.3ms
# 47:	learn: 6.1707957	total: 26.6ms	remaining: 56.6ms
# 48:	learn: 6.1589035	total: 27.2ms	remaining: 56ms
# 49:	learn: 6.1532980	total: 27.7ms	remaining: 55.4ms
# 50:	learn: 6.1428992	total: 28.2ms	remaining: 54.8ms
# 51:	learn: 6.1313779	total: 28.8ms	remaining: 54.2ms
# 52:	learn: 6.1148697	total: 29.3ms	remaining: 53.7ms
# 53:	learn: 6.0993130	total: 29.9ms	remaining: 53.1ms
# 54:	learn: 6.0881316	total: 30.4ms	remaining: 52.5ms
# 55:	learn: 6.0622471	total: 31ms	remaining: 52ms
# 56:	learn: 6.0435014	total: 31.5ms	remaining: 51.4ms
# 57:	learn: 6.0287980	total: 32ms	remaining: 50.7ms
# 58:	learn: 6.0062422	total: 32.5ms	remaining: 50.1ms
# 59:	learn: 5.9962649	total: 33ms	remaining: 49.5ms
# 60:	learn: 5.9870515	total: 33.5ms	remaining: 48.9ms
# 61:	learn: 5.9753515	total: 34.1ms	remaining: 48.4ms
# 62:	learn: 5.9670734	total: 34.6ms	remaining: 47.7ms
# 63:	learn: 5.9562979	total: 35.1ms	remaining: 47.1ms
# 64:	learn: 5.9452797	total: 35.5ms	remaining: 46.5ms
# 65:	learn: 5.9396615	total: 36.1ms	remaining: 46ms
# 66:	learn: 5.9345327	total: 36.6ms	remaining: 45.4ms
# 67:	learn: 5.9269236	total: 37.2ms	remaining: 44.8ms
# 68:	learn: 5.9013149	total: 37.7ms	remaining: 44.2ms
# 69:	learn: 5.8846836	total: 38.2ms	remaining: 43.6ms
# 70:	learn: 5.8822863	total: 38.7ms	remaining: 43.1ms
# 71:	learn: 5.8715035	total: 39.2ms	remaining: 42.4ms
# 72:	learn: 5.8606259	total: 39.7ms	remaining: 41.9ms
# 73:	learn: 5.8523559	total: 40.3ms	remaining: 41.4ms
# 74:	learn: 5.8418639	total: 40.9ms	remaining: 40.9ms
# 75:	learn: 5.8255746	total: 41.5ms	remaining: 40.4ms
# 76:	learn: 5.8072040	total: 42ms	remaining: 39.8ms
# 77:	learn: 5.7933527	total: 42.5ms	remaining: 39.3ms
# 78:	learn: 5.7818973	total: 43ms	remaining: 38.6ms
# 79:	learn: 5.7768114	total: 43.5ms	remaining: 38.1ms
# 80:	learn: 5.7690502	total: 44.1ms	remaining: 37.6ms
# 81:	learn: 5.7617131	total: 44.6ms	remaining: 37ms
# 82:	learn: 5.7537175	total: 45.1ms	remaining: 36.4ms
# 83:	learn: 5.7388923	total: 45.6ms	remaining: 35.8ms
# 84:	learn: 5.7328404	total: 46ms	remaining: 35.2ms
# 85:	learn: 5.7204921	total: 46.6ms	remaining: 34.7ms
# 86:	learn: 5.7115322	total: 47ms	remaining: 34ms
# 87:	learn: 5.7056372	total: 47.6ms	remaining: 33.5ms
# 88:	learn: 5.7009865	total: 48.1ms	remaining: 33ms
# 89:	learn: 5.6935258	total: 48.6ms	remaining: 32.4ms
# 90:	learn: 5.6881333	total: 49.2ms	remaining: 31.9ms
# 91:	learn: 5.6814067	total: 49.7ms	remaining: 31.3ms
# 92:	learn: 5.6759673	total: 50.3ms	remaining: 30.8ms
# 93:	learn: 5.6656973	total: 50.9ms	remaining: 30.3ms
# 94:	learn: 5.6570781	total: 51.4ms	remaining: 29.8ms
# 95:	learn: 5.6518764	total: 51.9ms	remaining: 29.2ms
# 96:	learn: 5.6435560	total: 52.5ms	remaining: 28.7ms
# 97:	learn: 5.6375529	total: 53ms	remaining: 28.1ms
# 98:	learn: 5.6319153	total: 53.5ms	remaining: 27.6ms
# 99:	learn: 5.6229006	total: 54ms	remaining: 27ms
# 100:	learn: 5.6167312	total: 54.5ms	remaining: 26.4ms
# 101:	learn: 5.6105169	total: 55ms	remaining: 25.9ms
# 102:	learn: 5.5995729	total: 55.5ms	remaining: 25.3ms
# 103:	learn: 5.5917892	total: 56ms	remaining: 24.8ms
# 104:	learn: 5.5859791	total: 56.5ms	remaining: 24.2ms
# 105:	learn: 5.5750400	total: 57.1ms	remaining: 23.7ms
# 106:	learn: 5.5697442	total: 57.7ms	remaining: 23.2ms
# 107:	learn: 5.5657424	total: 58.3ms	remaining: 22.7ms
# 108:	learn: 5.5614080	total: 58.8ms	remaining: 22.1ms
# 109:	learn: 5.5560745	total: 59.2ms	remaining: 21.5ms
# 110:	learn: 5.5506610	total: 59.8ms	remaining: 21ms
# 111:	learn: 5.5457028	total: 60.5ms	remaining: 20.5ms
# 112:	learn: 5.5419651	total: 61ms	remaining: 20ms
# 113:	learn: 5.5296796	total: 61.6ms	remaining: 19.4ms
# 114:	learn: 5.5249136	total: 62.1ms	remaining: 18.9ms
# 115:	learn: 5.5202570	total: 62.6ms	remaining: 18.3ms
# 116:	learn: 5.5166506	total: 63.2ms	remaining: 17.8ms
# 117:	learn: 5.5081754	total: 63.7ms	remaining: 17.3ms
# 118:	learn: 5.5020813	total: 64.2ms	remaining: 16.7ms
# 119:	learn: 5.4977394	total: 64.8ms	remaining: 16.2ms
# 120:	learn: 5.4948177	total: 65.4ms	remaining: 15.7ms
# 121:	learn: 5.4903197	total: 66ms	remaining: 15.1ms
# 122:	learn: 5.4849085	total: 66.5ms	remaining: 14.6ms
# 123:	learn: 5.4801547	total: 67ms	remaining: 14.1ms
# 124:	learn: 5.4770054	total: 67.5ms	remaining: 13.5ms
# 125:	learn: 5.4710743	total: 68ms	remaining: 13ms
# 126:	learn: 5.4634942	total: 68.6ms	remaining: 12.4ms
# 127:	learn: 5.4598447	total: 69.1ms	remaining: 11.9ms
# 128:	learn: 5.4550692	total: 69.7ms	remaining: 11.3ms
# 129:	learn: 5.4491246	total: 70.3ms	remaining: 10.8ms
# 130:	learn: 5.4460267	total: 70.9ms	remaining: 10.3ms
# 131:	learn: 5.4415460	total: 71.5ms	remaining: 9.75ms
# 132:	learn: 5.4365927	total: 72ms	remaining: 9.2ms
# 133:	learn: 5.4324936	total: 72.5ms	remaining: 8.66ms
# 134:	learn: 5.4288627	total: 73ms	remaining: 8.12ms
# 135:	learn: 5.4249345	total: 73.7ms	remaining: 7.58ms
# 136:	learn: 5.4218245	total: 74.2ms	remaining: 7.04ms
# 137:	learn: 5.4172279	total: 74.6ms	remaining: 6.49ms
# 138:	learn: 5.4141817	total: 75.2ms	remaining: 5.95ms
# 139:	learn: 5.4103919	total: 75.7ms	remaining: 5.41ms
# 140:	learn: 5.4068068	total: 76.3ms	remaining: 4.87ms
# 141:	learn: 5.4018579	total: 76.9ms	remaining: 4.33ms
# 142:	learn: 5.3864093	total: 77.5ms	remaining: 3.79ms
# 143:	learn: 5.3815082	total: 78ms	remaining: 3.25ms
# 144:	learn: 5.3788467	total: 78.5ms	remaining: 2.71ms
# 145:	learn: 5.3702543	total: 79.1ms	remaining: 2.17ms
# 146:	learn: 5.3672049	total: 79.6ms	remaining: 1.62ms
# 147:	learn: 5.3638449	total: 80ms	remaining: 1.08ms
# 148:	learn: 5.3585370	total: 80.6ms	remaining: 540us
# 149:	learn: 5.3548828	total: 81ms	remaining: 0us
# [CV] END .........depth=2, iterations=150, learning_rate=0.1; total time=   0.5s
# 0:	learn: 7.9885902	total: 621us	remaining: 92.6ms
# 1:	learn: 7.9035772	total: 1.31ms	remaining: 97.3ms
# 2:	learn: 7.8387959	total: 1.89ms	remaining: 92.6ms
# 3:	learn: 7.7969302	total: 2.47ms	remaining: 90.3ms
# 4:	learn: 7.7022896	total: 2.97ms	remaining: 86.2ms
# 5:	learn: 7.6586418	total: 3.45ms	remaining: 82.8ms
# 6:	learn: 7.6112202	total: 3.95ms	remaining: 80.7ms
# 7:	learn: 7.5590265	total: 4.41ms	remaining: 78.3ms
# 8:	learn: 7.5189411	total: 5.03ms	remaining: 78.8ms
# 9:	learn: 7.4810386	total: 5.53ms	remaining: 77.3ms
# 10:	learn: 7.4333313	total: 5.98ms	remaining: 75.5ms
# 11:	learn: 7.3779333	total: 6.47ms	remaining: 74.4ms
# 12:	learn: 7.3257167	total: 6.92ms	remaining: 72.9ms
# 13:	learn: 7.3047869	total: 7.45ms	remaining: 72.4ms
# 14:	learn: 7.2629139	total: 8.09ms	remaining: 72.8ms
# 15:	learn: 7.1960634	total: 8.63ms	remaining: 72.3ms
# 16:	learn: 7.1456246	total: 9.15ms	remaining: 71.6ms
# 17:	learn: 7.1144484	total: 9.65ms	remaining: 70.8ms
# 18:	learn: 7.0488045	total: 10.1ms	remaining: 69.8ms
# 19:	learn: 7.0129380	total: 10.6ms	remaining: 69.2ms
# 20:	learn: 6.9875107	total: 11.2ms	remaining: 68.5ms
# 21:	learn: 6.9214213	total: 11.7ms	remaining: 68.3ms
# 22:	learn: 6.9064309	total: 12.2ms	remaining: 67.5ms
# 23:	learn: 6.8335722	total: 12.7ms	remaining: 66.9ms
# 24:	learn: 6.8039606	total: 13.2ms	remaining: 66.1ms
# 25:	learn: 6.7503085	total: 13.8ms	remaining: 65.8ms
# 26:	learn: 6.7080534	total: 14.8ms	remaining: 67.3ms
# 27:	learn: 6.6821823	total: 15.4ms	remaining: 67.2ms
# 28:	learn: 6.6435472	total: 16ms	remaining: 66.8ms
# 29:	learn: 6.6070275	total: 16.5ms	remaining: 65.9ms
# 30:	learn: 6.5554636	total: 17ms	remaining: 65.4ms
# 31:	learn: 6.5460219	total: 17.6ms	remaining: 64.8ms
# 32:	learn: 6.5402619	total: 18.1ms	remaining: 64.1ms
# 33:	learn: 6.5227119	total: 18.6ms	remaining: 63.5ms
# 34:	learn: 6.5105274	total: 19.2ms	remaining: 62.9ms
# 35:	learn: 6.4976159	total: 19.7ms	remaining: 62.4ms
# 36:	learn: 6.4801746	total: 20.2ms	remaining: 61.7ms
# 37:	learn: 6.4641016	total: 20.8ms	remaining: 61.3ms
# 38:	learn: 6.4398474	total: 21.4ms	remaining: 60.8ms
# 39:	learn: 6.4307731	total: 21.9ms	remaining: 60.2ms
# 40:	learn: 6.4153822	total: 22.4ms	remaining: 59.6ms
# 41:	learn: 6.3956586	total: 23ms	remaining: 59ms
# 42:	learn: 6.3823259	total: 23.5ms	remaining: 58.5ms
# 43:	learn: 6.3657284	total: 24ms	remaining: 57.9ms
# 44:	learn: 6.3536486	total: 24.6ms	remaining: 57.3ms
# 45:	learn: 6.3448022	total: 25ms	remaining: 56.6ms
# 46:	learn: 6.3227949	total: 25.6ms	remaining: 56.1ms
# 47:	learn: 6.3103450	total: 26.1ms	remaining: 55.6ms
# 48:	learn: 6.3024423	total: 26.7ms	remaining: 55ms
# 49:	learn: 6.2986512	total: 27.1ms	remaining: 54.3ms
# 50:	learn: 6.2902332	total: 27.6ms	remaining: 53.6ms
# 51:	learn: 6.2778973	total: 28.1ms	remaining: 53ms
# 52:	learn: 6.2630423	total: 28.8ms	remaining: 52.7ms
# 53:	learn: 6.2506119	total: 29.3ms	remaining: 52.1ms
# 54:	learn: 6.2367347	total: 29.8ms	remaining: 51.4ms
# 55:	learn: 6.2035461	total: 30.3ms	remaining: 50.8ms
# 56:	learn: 6.1926609	total: 30.7ms	remaining: 50.1ms
# 57:	learn: 6.1789570	total: 31.3ms	remaining: 49.7ms
# 58:	learn: 6.1668305	total: 31.8ms	remaining: 49.1ms
# 59:	learn: 6.1507759	total: 32.4ms	remaining: 48.5ms
# 60:	learn: 6.1282827	total: 32.9ms	remaining: 47.9ms
# 61:	learn: 6.1189368	total: 33.4ms	remaining: 47.4ms
# 62:	learn: 6.1012345	total: 33.9ms	remaining: 46.8ms
# 63:	learn: 6.0907193	total: 34.5ms	remaining: 46.3ms
# 64:	learn: 6.0673227	total: 35ms	remaining: 45.8ms
# 65:	learn: 6.0594502	total: 35.5ms	remaining: 45.2ms
# 66:	learn: 6.0511562	total: 36.1ms	remaining: 44.7ms
# 67:	learn: 6.0246864	total: 36.6ms	remaining: 44.2ms
# 68:	learn: 6.0107370	total: 37.2ms	remaining: 43.6ms
# 69:	learn: 5.9923823	total: 37.6ms	remaining: 43ms
# 70:	learn: 5.9814062	total: 38.2ms	remaining: 42.5ms
# 71:	learn: 5.9681752	total: 38.6ms	remaining: 41.8ms
# 72:	learn: 5.9557957	total: 39.2ms	remaining: 41.3ms
# 73:	learn: 5.9402711	total: 39.7ms	remaining: 40.7ms
# 74:	learn: 5.9311175	total: 40.2ms	remaining: 40.2ms
# 75:	learn: 5.9240785	total: 40.7ms	remaining: 39.6ms
# 76:	learn: 5.9111804	total: 41.2ms	remaining: 39.1ms
# 77:	learn: 5.8991948	total: 41.8ms	remaining: 38.6ms
# 78:	learn: 5.8815046	total: 42.2ms	remaining: 37.9ms
# 79:	learn: 5.8755347	total: 42.8ms	remaining: 37.4ms
# 80:	learn: 5.8650951	total: 43.3ms	remaining: 36.9ms
# 81:	learn: 5.8568113	total: 43.8ms	remaining: 36.3ms
# 82:	learn: 5.8480440	total: 44.3ms	remaining: 35.8ms
# 83:	learn: 5.8392353	total: 44.8ms	remaining: 35.2ms
# 84:	learn: 5.8307003	total: 45.3ms	remaining: 34.6ms
# 85:	learn: 5.8232795	total: 45.8ms	remaining: 34.1ms
# 86:	learn: 5.8111194	total: 46.3ms	remaining: 33.5ms
# 87:	learn: 5.8049561	total: 46.8ms	remaining: 33ms
# 88:	learn: 5.7956768	total: 47.4ms	remaining: 32.5ms
# 89:	learn: 5.7837213	total: 47.9ms	remaining: 31.9ms
# 90:	learn: 5.7742067	total: 48.3ms	remaining: 31.3ms
# 91:	learn: 5.7636601	total: 48.9ms	remaining: 30.8ms
# 92:	learn: 5.7561281	total: 49.4ms	remaining: 30.3ms
# 93:	learn: 5.7481233	total: 49.9ms	remaining: 29.7ms
# 94:	learn: 5.7418499	total: 50.5ms	remaining: 29.2ms
# 95:	learn: 5.7328025	total: 51ms	remaining: 28.7ms
# 96:	learn: 5.7223681	total: 51.5ms	remaining: 28.1ms
# 97:	learn: 5.7111981	total: 52ms	remaining: 27.6ms
# 98:	learn: 5.6998402	total: 52.5ms	remaining: 27ms
# 99:	learn: 5.6844584	total: 53ms	remaining: 26.5ms
# 100:	learn: 5.6746172	total: 53.5ms	remaining: 26ms
# 101:	learn: 5.6685685	total: 54ms	remaining: 25.4ms
# 102:	learn: 5.6614632	total: 54.6ms	remaining: 24.9ms
# 103:	learn: 5.6561269	total: 55.1ms	remaining: 24.4ms
# 104:	learn: 5.6480280	total: 55.7ms	remaining: 23.9ms
# 105:	learn: 5.6370577	total: 56.2ms	remaining: 23.3ms
# 106:	learn: 5.6300831	total: 56.8ms	remaining: 22.8ms
# 107:	learn: 5.6231716	total: 57.4ms	remaining: 22.3ms
# 108:	learn: 5.6181801	total: 57.9ms	remaining: 21.8ms
# 109:	learn: 5.6103480	total: 58.4ms	remaining: 21.3ms
# 110:	learn: 5.6033581	total: 59.1ms	remaining: 20.8ms
# 111:	learn: 5.5976076	total: 59.7ms	remaining: 20.3ms
# 112:	learn: 5.5846587	total: 60.3ms	remaining: 19.8ms
# 113:	learn: 5.5802148	total: 60.8ms	remaining: 19.2ms
# 114:	learn: 5.5686131	total: 61.3ms	remaining: 18.7ms
# 115:	learn: 5.5651563	total: 61.9ms	remaining: 18.1ms
# 116:	learn: 5.5607720	total: 62.4ms	remaining: 17.6ms
# 117:	learn: 5.5525053	total: 62.9ms	remaining: 17.1ms
# 118:	learn: 5.5479818	total: 63.4ms	remaining: 16.5ms
# 119:	learn: 5.5417336	total: 64ms	remaining: 16ms
# 120:	learn: 5.5329879	total: 64.5ms	remaining: 15.5ms
# 121:	learn: 5.5289881	total: 65.1ms	remaining: 14.9ms
# 122:	learn: 5.5230854	total: 65.6ms	remaining: 14.4ms
# 123:	learn: 5.5188329	total: 66ms	remaining: 13.8ms
# 124:	learn: 5.5084280	total: 66.5ms	remaining: 13.3ms
# 125:	learn: 5.5022633	total: 67.1ms	remaining: 12.8ms
# 126:	learn: 5.4945596	total: 67.6ms	remaining: 12.2ms
# 127:	learn: 5.4841917	total: 68.1ms	remaining: 11.7ms
# 128:	learn: 5.4769803	total: 68.5ms	remaining: 11.2ms
# 129:	learn: 5.4700957	total: 69.1ms	remaining: 10.6ms
# 130:	learn: 5.4663206	total: 69.6ms	remaining: 10.1ms
# 131:	learn: 5.4589551	total: 70.1ms	remaining: 9.56ms
# 132:	learn: 5.4535789	total: 70.6ms	remaining: 9.03ms
# 133:	learn: 5.4512529	total: 71.1ms	remaining: 8.49ms
# 134:	learn: 5.4440756	total: 71.6ms	remaining: 7.96ms
# 135:	learn: 5.4346636	total: 72.1ms	remaining: 7.42ms
# 136:	learn: 5.4279144	total: 72.7ms	remaining: 6.9ms
# 137:	learn: 5.4122397	total: 73.2ms	remaining: 6.37ms
# 138:	learn: 5.4083301	total: 73.7ms	remaining: 5.83ms
# 139:	learn: 5.4046337	total: 74.2ms	remaining: 5.3ms
# 140:	learn: 5.4012309	total: 74.8ms	remaining: 4.77ms
# 141:	learn: 5.3917163	total: 75.3ms	remaining: 4.24ms
# 142:	learn: 5.3867378	total: 75.8ms	remaining: 3.71ms
# 143:	learn: 5.3824648	total: 76.3ms	remaining: 3.18ms
# 144:	learn: 5.3798479	total: 76.8ms	remaining: 2.65ms
# 145:	learn: 5.3753833	total: 77.4ms	remaining: 2.12ms
# 146:	learn: 5.3725508	total: 78ms	remaining: 1.59ms
# 147:	learn: 5.3631595	total: 78.6ms	remaining: 1.06ms
# 148:	learn: 5.3591942	total: 79.1ms	remaining: 531us
# 149:	learn: 5.3550200	total: 79.7ms	remaining: 0us
# [CV] END .........depth=2, iterations=150, learning_rate=0.1; total time=   0.5s
# 0:	learn: 7.9154700	total: 669us	remaining: 99.7ms
# 1:	learn: 7.8186334	total: 1.41ms	remaining: 104ms
# 2:	learn: 7.7492159	total: 1.99ms	remaining: 97.7ms
# 3:	learn: 7.6834284	total: 2.58ms	remaining: 94.4ms
# 4:	learn: 7.6218354	total: 3.24ms	remaining: 94ms
# 5:	learn: 7.5784003	total: 3.79ms	remaining: 90.9ms
# 6:	learn: 7.5171385	total: 4.37ms	remaining: 89.4ms
# 7:	learn: 7.4328517	total: 4.93ms	remaining: 87.5ms
# 8:	learn: 7.3811567	total: 5.53ms	remaining: 86.6ms
# 9:	learn: 7.3393794	total: 6.11ms	remaining: 85.5ms
# 10:	learn: 7.2324650	total: 6.6ms	remaining: 83.4ms
# 11:	learn: 7.1948215	total: 7.13ms	remaining: 82.1ms
# 12:	learn: 7.1454762	total: 7.67ms	remaining: 80.8ms
# 13:	learn: 7.1070239	total: 8.28ms	remaining: 80.4ms
# 14:	learn: 7.0604439	total: 8.82ms	remaining: 79.4ms
# 15:	learn: 6.9846314	total: 9.35ms	remaining: 78.3ms
# 16:	learn: 6.9244891	total: 9.81ms	remaining: 76.8ms
# 17:	learn: 6.8798767	total: 10.3ms	remaining: 75.9ms
# 18:	learn: 6.8355498	total: 11ms	remaining: 75.7ms
# 19:	learn: 6.7964365	total: 11.6ms	remaining: 75.5ms
# 20:	learn: 6.7676847	total: 12.2ms	remaining: 74.9ms
# 21:	learn: 6.7290531	total: 12.7ms	remaining: 74.1ms
# 22:	learn: 6.6772891	total: 13.3ms	remaining: 73.4ms
# 23:	learn: 6.6386345	total: 13.8ms	remaining: 72.6ms
# 24:	learn: 6.6121077	total: 14.4ms	remaining: 71.8ms
# 25:	learn: 6.5987033	total: 14.9ms	remaining: 71ms
# 26:	learn: 6.5843124	total: 15.4ms	remaining: 70.2ms
# 27:	learn: 6.5555644	total: 16ms	remaining: 69.7ms
# 28:	learn: 6.5057822	total: 16.6ms	remaining: 69.1ms
# 29:	learn: 6.4987648	total: 17.1ms	remaining: 68.4ms
# 30:	learn: 6.4896548	total: 17.6ms	remaining: 67.7ms
# 31:	learn: 6.4805195	total: 18.3ms	remaining: 67.4ms
# 32:	learn: 6.4642700	total: 18.8ms	remaining: 66.7ms
# 33:	learn: 6.4441630	total: 19.4ms	remaining: 66.2ms
# 34:	learn: 6.4186949	total: 19.9ms	remaining: 65.4ms
# 35:	learn: 6.4015164	total: 20.4ms	remaining: 64.7ms
# 36:	learn: 6.3839827	total: 21ms	remaining: 64ms
# 37:	learn: 6.3660487	total: 21.5ms	remaining: 63.3ms
# 38:	learn: 6.3425063	total: 22ms	remaining: 62.5ms
# 39:	learn: 6.3081361	total: 22.5ms	remaining: 61.7ms
# 40:	learn: 6.2961233	total: 23ms	remaining: 61.1ms
# 41:	learn: 6.2832537	total: 23.6ms	remaining: 60.7ms
# 42:	learn: 6.2560630	total: 24.2ms	remaining: 60.1ms
# 43:	learn: 6.2357613	total: 24.7ms	remaining: 59.5ms
# 44:	learn: 6.2217100	total: 25.3ms	remaining: 58.9ms
# 45:	learn: 6.2065240	total: 25.8ms	remaining: 58.3ms
# 46:	learn: 6.1957483	total: 26.3ms	remaining: 57.6ms
# 47:	learn: 6.1867095	total: 26.8ms	remaining: 57ms
# 48:	learn: 6.1802448	total: 27.3ms	remaining: 56.3ms
# 49:	learn: 6.1705138	total: 27.8ms	remaining: 55.7ms
# 50:	learn: 6.1612740	total: 28.5ms	remaining: 55.3ms
# 51:	learn: 6.1425568	total: 29ms	remaining: 54.7ms
# 52:	learn: 6.1144926	total: 29.5ms	remaining: 54ms
# 53:	learn: 6.1079731	total: 30ms	remaining: 53.4ms
# 54:	learn: 6.0989593	total: 30.6ms	remaining: 52.8ms
# 55:	learn: 6.0852493	total: 31.1ms	remaining: 52.2ms
# 56:	learn: 6.0753859	total: 31.6ms	remaining: 51.6ms
# 57:	learn: 6.0670968	total: 32.1ms	remaining: 51ms
# 58:	learn: 6.0437211	total: 32.6ms	remaining: 50.3ms
# 59:	learn: 6.0370459	total: 33.1ms	remaining: 49.7ms
# 60:	learn: 6.0130637	total: 33.6ms	remaining: 49ms
# 61:	learn: 6.0005880	total: 34.1ms	remaining: 48.5ms
# 62:	learn: 5.9924072	total: 34.6ms	remaining: 47.8ms
# 63:	learn: 5.9798593	total: 35.1ms	remaining: 47.2ms
# 64:	learn: 5.9681168	total: 35.7ms	remaining: 46.6ms
# 65:	learn: 5.9635321	total: 36.2ms	remaining: 46.1ms
# 66:	learn: 5.9484242	total: 36.8ms	remaining: 45.5ms
# 67:	learn: 5.9364400	total: 37.3ms	remaining: 45ms
# 68:	learn: 5.9260689	total: 37.8ms	remaining: 44.4ms
# 69:	learn: 5.9196197	total: 38.3ms	remaining: 43.8ms
# 70:	learn: 5.9013170	total: 38.9ms	remaining: 43.2ms
# 71:	learn: 5.8911468	total: 39.4ms	remaining: 42.7ms
# 72:	learn: 5.8773200	total: 39.9ms	remaining: 42.1ms
# 73:	learn: 5.8696689	total: 40.3ms	remaining: 41.4ms
# 74:	learn: 5.8613142	total: 40.9ms	remaining: 40.9ms
# 75:	learn: 5.8478047	total: 41.4ms	remaining: 40.3ms
# 76:	learn: 5.8400598	total: 41.9ms	remaining: 39.7ms
# 77:	learn: 5.8301257	total: 42.4ms	remaining: 39.2ms
# 78:	learn: 5.8239499	total: 43ms	remaining: 38.7ms
# 79:	learn: 5.8173069	total: 43.5ms	remaining: 38.1ms
# 80:	learn: 5.7991914	total: 44ms	remaining: 37.5ms
# 81:	learn: 5.7888891	total: 44.5ms	remaining: 36.9ms
# 82:	learn: 5.7766220	total: 45ms	remaining: 36.4ms
# 83:	learn: 5.7610248	total: 45.5ms	remaining: 35.8ms
# 84:	learn: 5.7523649	total: 46ms	remaining: 35.2ms
# 85:	learn: 5.7432005	total: 46.6ms	remaining: 34.7ms
# 86:	learn: 5.7362332	total: 47.1ms	remaining: 34.1ms
# 87:	learn: 5.7206519	total: 47.7ms	remaining: 33.6ms
# 88:	learn: 5.7090085	total: 48.2ms	remaining: 33ms
# 89:	learn: 5.7036076	total: 48.7ms	remaining: 32.5ms
# 90:	learn: 5.6948148	total: 49.2ms	remaining: 31.9ms
# 91:	learn: 5.6867568	total: 49.8ms	remaining: 31.4ms
# 92:	learn: 5.6778822	total: 50.3ms	remaining: 30.8ms
# 93:	learn: 5.6596028	total: 50.8ms	remaining: 30.3ms
# 94:	learn: 5.6405957	total: 51.3ms	remaining: 29.7ms
# 95:	learn: 5.6307905	total: 51.8ms	remaining: 29.1ms
# 96:	learn: 5.6224503	total: 52.3ms	remaining: 28.6ms
# 97:	learn: 5.6134819	total: 52.9ms	remaining: 28ms
# 98:	learn: 5.6031896	total: 53.4ms	remaining: 27.5ms
# 99:	learn: 5.5973965	total: 53.9ms	remaining: 26.9ms
# 100:	learn: 5.5876691	total: 54.5ms	remaining: 26.4ms
# 101:	learn: 5.5773725	total: 55ms	remaining: 25.9ms
# 102:	learn: 5.5664304	total: 55.5ms	remaining: 25.3ms
# 103:	learn: 5.5588545	total: 56ms	remaining: 24.8ms
# 104:	learn: 5.5486110	total: 56.5ms	remaining: 24.2ms
# 105:	learn: 5.5409063	total: 57ms	remaining: 23.7ms
# 106:	learn: 5.5349018	total: 57.5ms	remaining: 23.1ms
# 107:	learn: 5.5277279	total: 58ms	remaining: 22.6ms
# 108:	learn: 5.5231993	total: 58.5ms	remaining: 22ms
# 109:	learn: 5.5137783	total: 59ms	remaining: 21.5ms
# 110:	learn: 5.5083602	total: 59.5ms	remaining: 20.9ms
# 111:	learn: 5.5002148	total: 60ms	remaining: 20.4ms
# 112:	learn: 5.4956114	total: 60.6ms	remaining: 19.8ms
# 113:	learn: 5.4823087	total: 61.1ms	remaining: 19.3ms
# 114:	learn: 5.4784392	total: 61.6ms	remaining: 18.7ms
# 115:	learn: 5.4742384	total: 62.1ms	remaining: 18.2ms
# 116:	learn: 5.4669397	total: 62.7ms	remaining: 17.7ms
# 117:	learn: 5.4632017	total: 63.2ms	remaining: 17.1ms
# 118:	learn: 5.4579764	total: 63.7ms	remaining: 16.6ms
# 119:	learn: 5.4540302	total: 64.2ms	remaining: 16ms
# 120:	learn: 5.4425701	total: 64.6ms	remaining: 15.5ms
# 121:	learn: 5.4368922	total: 65.2ms	remaining: 15ms
# 122:	learn: 5.4331453	total: 65.7ms	remaining: 14.4ms
# 123:	learn: 5.4262724	total: 66.2ms	remaining: 13.9ms
# 124:	learn: 5.4242553	total: 66.8ms	remaining: 13.4ms
# 125:	learn: 5.4201162	total: 67.3ms	remaining: 12.8ms
# 126:	learn: 5.4125520	total: 67.8ms	remaining: 12.3ms
# 127:	learn: 5.4077169	total: 68.4ms	remaining: 11.8ms
# 128:	learn: 5.4000315	total: 68.9ms	remaining: 11.2ms
# 129:	learn: 5.3903190	total: 69.5ms	remaining: 10.7ms
# 130:	learn: 5.3859741	total: 70ms	remaining: 10.2ms
# 131:	learn: 5.3791639	total: 70.5ms	remaining: 9.61ms
# 132:	learn: 5.3738448	total: 71ms	remaining: 9.08ms
# 133:	learn: 5.3707496	total: 71.5ms	remaining: 8.54ms
# 134:	learn: 5.3671875	total: 72.1ms	remaining: 8.01ms
# 135:	learn: 5.3626929	total: 72.6ms	remaining: 7.47ms
# 136:	learn: 5.3576522	total: 73.1ms	remaining: 6.94ms
# 137:	learn: 5.3533571	total: 73.6ms	remaining: 6.4ms
# 138:	learn: 5.3486974	total: 74.1ms	remaining: 5.87ms
# 139:	learn: 5.3433580	total: 74.8ms	remaining: 5.34ms
# 140:	learn: 5.3375720	total: 75.4ms	remaining: 4.81ms
# 141:	learn: 5.3341949	total: 75.9ms	remaining: 4.28ms
# 142:	learn: 5.3264910	total: 76.5ms	remaining: 3.74ms
# 143:	learn: 5.3237893	total: 77ms	remaining: 3.21ms
# 144:	learn: 5.3175050	total: 77.5ms	remaining: 2.67ms
# 145:	learn: 5.3107164	total: 78.1ms	remaining: 2.14ms
# 146:	learn: 5.3023039	total: 78.7ms	remaining: 1.6ms
# 147:	learn: 5.2985946	total: 79.2ms	remaining: 1.07ms
# 148:	learn: 5.2961504	total: 79.8ms	remaining: 535us
# 149:	learn: 5.2932191	total: 80.3ms	remaining: 0us
# [CV] END .........depth=2, iterations=150, learning_rate=0.1; total time=   0.6s
# 0:	learn: 7.5688571	total: 4.72ms	remaining: 561ms
# 1:	learn: 7.4026374	total: 9.43ms	remaining: 556ms
# 2:	learn: 7.2528450	total: 13.7ms	remaining: 536ms
# 3:	learn: 7.0268889	total: 18.4ms	remaining: 535ms
# 4:	learn: 6.8373064	total: 22.8ms	remaining: 525ms
# 5:	learn: 6.6741228	total: 27.1ms	remaining: 515ms
# 6:	learn: 6.5381633	total: 31.3ms	remaining: 505ms
# 7:	learn: 6.4063277	total: 35.6ms	remaining: 498ms
# 8:	learn: 6.2926999	total: 40ms	remaining: 494ms
# 9:	learn: 6.2266373	total: 44.7ms	remaining: 492ms
# 10:	learn: 6.1256382	total: 48.9ms	remaining: 485ms
# 11:	learn: 6.0086865	total: 53ms	remaining: 477ms
# 12:	learn: 5.9207977	total: 57.3ms	remaining: 471ms
# ...
# 49:	learn: 3.3213570	total: 84.4ms	remaining: 84.4ms
# 50:	learn: 3.3023494	total: 86.1ms	remaining: 82.7ms
# 51:	learn: 3.2824473	total: 87.8ms	remaining: 81ms
# 52:	learn: 3.2625510	total: 89.3ms	remaining: 79.2ms
# 53:	learn: 3.2426782	total: 91.1ms	remaining: 77.6ms
# 54:	learn: 3.1943346	total: 92.9ms	remaining: 76ms
# 55:	learn: 3.1752669	total: 94.8ms	remaining: 74.5ms
# 56:	learn: 3.1450595	total: 96.4ms	remaining: 72.8ms
# 57:	learn: 3.1355056	total: 98.1ms	remaining: 71ms
# 58:	learn: 3.1138061	total: 99.8ms	remaining: 69.3ms
# 59:	learn: 3.0973492	total: 101ms	remaining: 67.6ms
# 60:	learn: 3.0920741	total: 103ms	remaining: 65.9ms
# 61:	learn: 3.0721075	total: 105ms	remaining: 64.2ms
# 62:	learn: 3.0470839	total: 107ms	remaining: 62.6ms
# 63:	learn: 3.0366211	total: 108ms	remaining: 60.9ms
# 64:	learn: 3.0106283	total: 110ms	remaining: 59.2ms
# 65:	learn: 3.0026705	total: 112ms	remaining: 57.5ms
# 66:	learn: 2.9818401	total: 113ms	remaining: 55.9ms
# 67:	learn: 2.9773987	total: 115ms	remaining: 54.1ms
# 68:	learn: 2.9616300	total: 117ms	remaining: 52.4ms
# 69:	learn: 2.9373064	total: 118ms	remaining: 50.6ms
# 70:	learn: 2.9275419	total: 120ms	remaining: 49ms
# 71:	learn: 2.9127109	total: 122ms	remaining: 47.3ms
# 72:	learn: 2.9073221	total: 124ms	remaining: 45.7ms
# 73:	learn: 2.8786602	total: 125ms	remaining: 44ms
# 74:	learn: 2.8638808	total: 127ms	remaining: 42.3ms
# 75:	learn: 2.8535280	total: 129ms	remaining: 40.6ms
# 76:	learn: 2.8462438	total: 130ms	remaining: 38.9ms
# 77:	learn: 2.8440969	total: 132ms	remaining: 37.2ms
# 78:	learn: 2.8070880	total: 134ms	remaining: 35.5ms
# 79:	learn: 2.7852452	total: 135ms	remaining: 33.8ms
# 80:	learn: 2.7749835	total: 137ms	remaining: 32ms
# 81:	learn: 2.7669427	total: 138ms	remaining: 30.3ms
# 82:	learn: 2.7542311	total: 140ms	remaining: 28.6ms
# 83:	learn: 2.7381563	total: 141ms	remaining: 26.9ms
# 84:	learn: 2.7221138	total: 143ms	remaining: 25.2ms
# 85:	learn: 2.7083130	total: 145ms	remaining: 23.5ms
# 86:	learn: 2.6757569	total: 146ms	remaining: 21.9ms
# 87:	learn: 2.6659070	total: 148ms	remaining: 20.2ms
# 88:	learn: 2.6614479	total: 149ms	remaining: 18.5ms
# 89:	learn: 2.6454707	total: 151ms	remaining: 16.8ms
# 90:	learn: 2.6430985	total: 152ms	remaining: 15.1ms
# 91:	learn: 2.6250104	total: 154ms	remaining: 13.4ms
# 92:	learn: 2.6188639	total: 156ms	remaining: 11.7ms
# 93:	learn: 2.6170638	total: 157ms	remaining: 10ms
# 94:	learn: 2.6067993	total: 159ms	remaining: 8.37ms
# 95:	learn: 2.6031009	total: 161ms	remaining: 6.69ms
# 96:	learn: 2.6024426	total: 162ms	remaining: 5.02ms
# 97:	learn: 2.5927655	total: 165ms	remaining: 3.36ms
# 98:	learn: 2.5862439	total: 166ms	remaining: 1.68ms
# 99:	learn: 2.5788683	total: 168ms	remaining: 0us
# [CV] END ...........depth=5, iterations=100, learning_rate=1; total time=   0.7s
# 0:	learn: 6.9248046	total: 1.69ms	remaining: 167ms
# 1:	learn: 6.3033698	total: 3.44ms	remaining: 169ms
# 2:	learn: 5.8444243	total: 5.01ms	remaining: 162ms
# 3:	learn: 5.6758849	total: 6.71ms	remaining: 161ms
# 4:	learn: 5.5808114	total: 8.29ms	remaining: 157ms
# 5:	learn: 5.4606729	total: 9.85ms	remaining: 154ms
# 6:	learn: 5.2800334	total: 11.5ms	remaining: 153ms
# 7:	learn: 5.1313730	total: 13ms	remaining: 150ms
# 8:	learn: 4.9749338	total: 14.6ms	remaining: 148ms
# 9:	learn: 4.8703527	total: 16.2ms	remaining: 145ms
# 10:	learn: 4.7389783	total: 17.7ms	remaining: 143ms
# 11:	learn: 4.6205689	total: 19.3ms	remaining: 141ms
# 12:	learn: 4.5445097	total: 20.8ms	remaining: 139ms
# 13:	learn: 4.4252358	total: 22.3ms	remaining: 137ms
# 14:	learn: 4.3725132	total: 23.9ms	remaining: 135ms
# 15:	learn: 4.2860838	total: 25.3ms	remaining: 133ms
# 16:	learn: 4.2497820	total: 27ms	remaining: 132ms
# 17:	learn: 4.1694006	total: 28.6ms	remaining: 130ms
# 18:	learn: 4.1037124	total: 30.1ms	remaining: 129ms
# 19:	learn: 4.0475322	total: 32ms	remaining: 128ms
# 20:	learn: 3.9827099	total: 33.6ms	remaining: 126ms
# 21:	learn: 3.9394943	total: 35.1ms	remaining: 125ms
# 22:	learn: 3.9325792	total: 36.6ms	remaining: 122ms
# 23:	learn: 3.8962789	total: 38.2ms	remaining: 121ms
# 24:	learn: 3.8746715	total: 39.8ms	remaining: 119ms
# 25:	learn: 3.8392354	total: 41.4ms	remaining: 118ms
# 26:	learn: 3.8003417	total: 43ms	remaining: 116ms
# 27:	learn: 3.7441605	total: 44.6ms	remaining: 115ms
# 28:	learn: 3.6897059	total: 46.4ms	remaining: 114ms
# 29:	learn: 3.6724206	total: 48ms	remaining: 112ms
# 30:	learn: 3.6534090	total: 49.5ms	remaining: 110ms
# 31:	learn: 3.6326661	total: 51ms	remaining: 108ms
# 32:	learn: 3.5859931	total: 52.5ms	remaining: 107ms
# 33:	learn: 3.5177154	total: 54.1ms	remaining: 105ms
# 34:	learn: 3.4693121	total: 55.6ms	remaining: 103ms
# 35:	learn: 3.4416518	total: 57.1ms	remaining: 102ms
# 36:	learn: 3.3984359	total: 58.7ms	remaining: 99.9ms
# 37:	learn: 3.3863245	total: 60.3ms	remaining: 98.3ms
# 38:	learn: 3.3733589	total: 61.9ms	remaining: 96.7ms
# 39:	learn: 3.3560728	total: 63.5ms	remaining: 95.2ms
# 40:	learn: 3.3215040	total: 65.2ms	remaining: 93.9ms
# 41:	learn: 3.3085413	total: 66.9ms	remaining: 92.4ms
# 42:	learn: 3.2843455	total: 68.6ms	remaining: 90.9ms
# 43:	learn: 3.2592741	total: 70.2ms	remaining: 89.4ms
# 44:	learn: 3.2151937	total: 71.9ms	remaining: 87.8ms
# 45:	learn: 3.1901241	total: 73.5ms	remaining: 86.3ms
# 46:	learn: 3.1814729	total: 75ms	remaining: 84.6ms
# 47:	learn: 3.1676397	total: 76.7ms	remaining: 83.1ms
# 48:	learn: 3.1442990	total: 78.5ms	remaining: 81.7ms
# 49:	learn: 3.1330577	total: 80.1ms	remaining: 80.1ms
# 50:	learn: 3.1054035	total: 81.8ms	remaining: 78.6ms
# 51:	learn: 3.0915678	total: 83.5ms	remaining: 77.1ms
# 52:	learn: 3.0846513	total: 85.2ms	remaining: 75.5ms
# 53:	learn: 3.0777228	total: 87.2ms	remaining: 74.3ms
# 54:	learn: 3.0690828	total: 88.7ms	remaining: 72.6ms
# 55:	learn: 3.0509507	total: 90.4ms	remaining: 71.1ms
# 56:	learn: 3.0051418	total: 92ms	remaining: 69.4ms
# 57:	learn: 3.0042737	total: 93.5ms	remaining: 67.7ms
# 58:	learn: 2.9818001	total: 95.1ms	remaining: 66.1ms
# 59:	learn: 2.9774650	total: 96.6ms	remaining: 64.4ms
# 60:	learn: 2.9644876	total: 98.2ms	remaining: 62.8ms
# 61:	learn: 2.9644741	total: 99.8ms	remaining: 61.2ms
# 62:	learn: 2.9480391	total: 101ms	remaining: 59.6ms
# 63:	learn: 2.9393551	total: 103ms	remaining: 57.9ms
# 64:	learn: 2.9255182	total: 105ms	remaining: 56.3ms
# 65:	learn: 2.9237811	total: 106ms	remaining: 54.7ms
# 66:	learn: 2.9056254	total: 108ms	remaining: 53.4ms
# 67:	learn: 2.8987006	total: 111ms	remaining: 52.3ms
# 68:	learn: 2.8926461	total: 113ms	remaining: 51ms
# 69:	learn: 2.8796762	total: 116ms	remaining: 49.7ms
# 70:	learn: 2.8649633	total: 119ms	remaining: 48.4ms
# 71:	learn: 2.8623588	total: 121ms	remaining: 46.9ms
# 72:	learn: 2.8511080	total: 122ms	remaining: 45.2ms
# 73:	learn: 2.8398743	total: 124ms	remaining: 43.6ms
# 74:	learn: 2.8329158	total: 126ms	remaining: 41.9ms
# 75:	learn: 2.8242941	total: 127ms	remaining: 40.2ms
# 76:	learn: 2.8087306	total: 129ms	remaining: 38.5ms
# 77:	learn: 2.8061225	total: 130ms	remaining: 36.8ms
# 78:	learn: 2.7827921	total: 132ms	remaining: 35.1ms
# 79:	learn: 2.7793319	total: 134ms	remaining: 33.4ms
# 80:	learn: 2.7732675	total: 135ms	remaining: 31.8ms
# 81:	learn: 2.7697905	total: 137ms	remaining: 30ms
# 82:	learn: 2.7611581	total: 139ms	remaining: 28.4ms
# 83:	learn: 2.7473023	total: 140ms	remaining: 26.7ms
# 84:	learn: 2.7334329	total: 142ms	remaining: 25ms
# 85:	learn: 2.7221875	total: 144ms	remaining: 23.4ms
# 86:	learn: 2.7177910	total: 145ms	remaining: 21.7ms
# 87:	learn: 2.7108127	total: 147ms	remaining: 20ms
# 88:	learn: 2.7004627	total: 149ms	remaining: 18.4ms
# 89:	learn: 2.6943636	total: 151ms	remaining: 16.7ms
# 90:	learn: 2.6857158	total: 152ms	remaining: 15.1ms
# 91:	learn: 2.6847789	total: 154ms	remaining: 13.4ms
# 92:	learn: 2.6847501	total: 155ms	remaining: 11.7ms
# 93:	learn: 2.6829571	total: 157ms	remaining: 10ms
# 94:	learn: 2.6794559	total: 159ms	remaining: 8.35ms
# 95:	learn: 2.6656701	total: 160ms	remaining: 6.67ms
# 96:	learn: 2.6500919	total: 162ms	remaining: 5ms
# 97:	learn: 2.6431627	total: 165ms	remaining: 3.36ms
# 98:	learn: 2.6422782	total: 166ms	remaining: 1.68ms
# 99:	learn: 2.6387876	total: 168ms	remaining: 0us
# [CV] END ...........depth=5, iterations=100, learning_rate=1; total time=   0.8s
# 0:	learn: 7.9027079	total: 834us	remaining: 124ms
# 1:	learn: 7.8296877	total: 1.62ms	remaining: 120ms
# 2:	learn: 7.7172445	total: 2.34ms	remaining: 115ms
# 3:	learn: 7.6257430	total: 3.04ms	remaining: 111ms
# 4:	learn: 7.5327972	total: 3.68ms	remaining: 107ms
# 5:	learn: 7.4838436	total: 4.34ms	remaining: 104ms
# 6:	learn: 7.4221768	total: 4.98ms	remaining: 102ms
# 7:	learn: 7.3676180	total: 5.64ms	remaining: 100ms
# 8:	learn: 7.3090099	total: 6.29ms	remaining: 98.5ms
# 9:	learn: 7.2777945	total: 6.9ms	remaining: 96.6ms
# 10:	learn: 7.2420569	total: 7.5ms	remaining: 94.7ms
# 11:	learn: 7.1779573	total: 8.09ms	remaining: 93ms
# 12:	learn: 7.1321976	total: 8.65ms	remaining: 91.1ms
# 13:	learn: 7.1066070	total: 9.2ms	remaining: 89.4ms
# 14:	learn: 7.0272130	total: 9.69ms	remaining: 87.2ms
# 15:	learn: 6.9925279	total: 10.3ms	remaining: 85.9ms
# 16:	learn: 6.9479714	total: 10.8ms	remaining: 84.7ms
# 17:	learn: 6.9242793	total: 11.4ms	remaining: 83.9ms
# 18:	learn: 6.8712340	total: 12ms	remaining: 83.1ms
# 19:	learn: 6.8424796	total: 12.6ms	remaining: 81.9ms
# 20:	learn: 6.8219736	total: 13.2ms	remaining: 81.3ms
# 21:	learn: 6.7816042	total: 13.9ms	remaining: 80.7ms
# 22:	learn: 6.7563535	total: 14.5ms	remaining: 79.9ms
# 23:	learn: 6.7353576	total: 15ms	remaining: 79ms
# 24:	learn: 6.7223417	total: 15.6ms	remaining: 78ms
# 25:	learn: 6.6843098	total: 16.3ms	remaining: 77.7ms
# 26:	learn: 6.6500674	total: 16.9ms	remaining: 77ms
# 27:	learn: 6.6254322	total: 17.5ms	remaining: 76.4ms
# 28:	learn: 6.5783747	total: 18.2ms	remaining: 75.9ms
# 29:	learn: 6.5501422	total: 18.8ms	remaining: 75.3ms
# 30:	learn: 6.5361600	total: 19.4ms	remaining: 74.5ms
# 31:	learn: 6.5225689	total: 19.9ms	remaining: 73.5ms
# 32:	learn: 6.4942241	total: 20.5ms	remaining: 72.6ms
# 33:	learn: 6.4824359	total: 21ms	remaining: 71.8ms
# 34:	learn: 6.4396935	total: 21.6ms	remaining: 71ms
# 35:	learn: 6.4245958	total: 22.2ms	remaining: 70.2ms
# 36:	learn: 6.4116019	total: 22.7ms	remaining: 69.4ms
# 37:	learn: 6.3984203	total: 23.3ms	remaining: 68.8ms
# 38:	learn: 6.3774101	total: 24ms	remaining: 68.3ms
# 39:	learn: 6.3673770	total: 24.6ms	remaining: 67.7ms
# 40:	learn: 6.3610394	total: 25.2ms	remaining: 67ms
# 41:	learn: 6.3437697	total: 25.7ms	remaining: 66.2ms
# 42:	learn: 6.3338330	total: 26.3ms	remaining: 65.6ms
# 43:	learn: 6.3050355	total: 27ms	remaining: 65ms
# 44:	learn: 6.2758370	total: 27.6ms	remaining: 64.3ms
# 45:	learn: 6.2630672	total: 28.1ms	remaining: 63.6ms
# 46:	learn: 6.2544083	total: 28.7ms	remaining: 63ms
# 47:	learn: 6.2384711	total: 29.4ms	remaining: 62.4ms
# 48:	learn: 6.2218245	total: 30ms	remaining: 61.8ms
# 49:	learn: 6.2104513	total: 30.6ms	remaining: 61.3ms
# 50:	learn: 6.1974615	total: 31.2ms	remaining: 60.6ms
# 51:	learn: 6.1869345	total: 31.8ms	remaining: 60ms
# 52:	learn: 6.1665413	total: 32.5ms	remaining: 59.4ms
# 53:	learn: 6.1584581	total: 33ms	remaining: 58.7ms
# 54:	learn: 6.1470992	total: 33.6ms	remaining: 58ms
# 55:	learn: 6.1395029	total: 34.1ms	remaining: 57.3ms
# 56:	learn: 6.1268250	total: 34.7ms	remaining: 56.6ms
# 57:	learn: 6.1047470	total: 35.3ms	remaining: 55.9ms
# 58:	learn: 6.0981068	total: 35.9ms	remaining: 55.3ms
# 59:	learn: 6.0857662	total: 36.4ms	remaining: 54.6ms
# 60:	learn: 6.0786008	total: 37ms	remaining: 54.1ms
# 61:	learn: 6.0703246	total: 37.7ms	remaining: 53.4ms
# 62:	learn: 6.0644282	total: 38.2ms	remaining: 52.8ms
# 63:	learn: 6.0558922	total: 38.9ms	remaining: 52.2ms
# 64:	learn: 6.0391894	total: 39.5ms	remaining: 51.6ms
# 65:	learn: 6.0291056	total: 40.1ms	remaining: 51ms
# 66:	learn: 6.0209817	total: 40.7ms	remaining: 50.4ms
# 67:	learn: 6.0145592	total: 41.3ms	remaining: 49.9ms
# 68:	learn: 6.0025519	total: 41.9ms	remaining: 49.2ms
# 69:	learn: 5.9965603	total: 42.6ms	remaining: 48.7ms
# 70:	learn: 5.9904359	total: 43.2ms	remaining: 48ms
# 71:	learn: 5.9855434	total: 43.9ms	remaining: 47.5ms
# 72:	learn: 5.9735842	total: 44.5ms	remaining: 46.9ms
# 73:	learn: 5.9639696	total: 45.1ms	remaining: 46.4ms
# 74:	learn: 5.9566083	total: 45.7ms	remaining: 45.7ms
# 75:	learn: 5.9523443	total: 46.3ms	remaining: 45.1ms
# 76:	learn: 5.9407266	total: 46.9ms	remaining: 44.5ms
# 77:	learn: 5.9286174	total: 47.5ms	remaining: 43.9ms
# 78:	learn: 5.9196255	total: 48.2ms	remaining: 43.3ms
# 79:	learn: 5.9070583	total: 48.8ms	remaining: 42.7ms
# 80:	learn: 5.8952755	total: 49.5ms	remaining: 42.1ms
# 81:	learn: 5.8899460	total: 50.1ms	remaining: 41.5ms
# 82:	learn: 5.8781446	total: 50.7ms	remaining: 40.9ms
# 83:	learn: 5.8613521	total: 51.3ms	remaining: 40.3ms
# 84:	learn: 5.8541050	total: 51.9ms	remaining: 39.7ms
# 85:	learn: 5.8432022	total: 52.5ms	remaining: 39ms
# 86:	learn: 5.8261896	total: 53.1ms	remaining: 38.5ms
# 87:	learn: 5.8153312	total: 53.8ms	remaining: 37.9ms
# 88:	learn: 5.8075881	total: 54.4ms	remaining: 37.3ms
# 89:	learn: 5.8020101	total: 55ms	remaining: 36.7ms
# 90:	learn: 5.7928297	total: 55.6ms	remaining: 36.1ms
# 91:	learn: 5.7852200	total: 56.3ms	remaining: 35.5ms
# 92:	learn: 5.7793048	total: 56.9ms	remaining: 34.9ms
# 93:	learn: 5.7726709	total: 57.5ms	remaining: 34.3ms
# 94:	learn: 5.7645161	total: 58.2ms	remaining: 33.7ms
# 95:	learn: 5.7563917	total: 58.8ms	remaining: 33.1ms
# 96:	learn: 5.7482799	total: 59.4ms	remaining: 32.4ms
# 97:	learn: 5.7350387	total: 60ms	remaining: 31.8ms
# 98:	learn: 5.7294114	total: 60.5ms	remaining: 31.2ms
# 99:	learn: 5.7207912	total: 61.1ms	remaining: 30.6ms
# 100:	learn: 5.7157233	total: 61.7ms	remaining: 29.9ms
# 101:	learn: 5.7096860	total: 62.4ms	remaining: 29.4ms
# 102:	learn: 5.7017394	total: 63ms	remaining: 28.7ms
# 103:	learn: 5.6919790	total: 63.6ms	remaining: 28.1ms
# 104:	learn: 5.6848522	total: 64.3ms	remaining: 27.5ms
# 105:	learn: 5.6790438	total: 64.9ms	remaining: 26.9ms
# 106:	learn: 5.6718881	total: 65.4ms	remaining: 26.3ms
# 107:	learn: 5.6658189	total: 66ms	remaining: 25.7ms
# 108:	learn: 5.6602144	total: 66.6ms	remaining: 25.1ms
# 109:	learn: 5.6552169	total: 67.2ms	remaining: 24.5ms
# 110:	learn: 5.6493749	total: 67.9ms	remaining: 23.8ms
# 111:	learn: 5.6437286	total: 68.5ms	remaining: 23.2ms
# 112:	learn: 5.6389403	total: 69.2ms	remaining: 22.6ms
# 113:	learn: 5.6299539	total: 69.8ms	remaining: 22ms
# 114:	learn: 5.6235832	total: 70.3ms	remaining: 21.4ms
# 115:	learn: 5.6141019	total: 71ms	remaining: 20.8ms
# 116:	learn: 5.6069276	total: 71.6ms	remaining: 20.2ms
# 117:	learn: 5.6035739	total: 72.2ms	remaining: 19.6ms
# 118:	learn: 5.6009059	total: 72.8ms	remaining: 19ms
# 119:	learn: 5.5978526	total: 73.4ms	remaining: 18.4ms
# 120:	learn: 5.5924450	total: 74ms	remaining: 17.7ms
# 121:	learn: 5.5841872	total: 74.6ms	remaining: 17.1ms
# 122:	learn: 5.5788721	total: 75.2ms	remaining: 16.5ms
# 123:	learn: 5.5750003	total: 75.9ms	remaining: 15.9ms
# 124:	learn: 5.5719133	total: 76.5ms	remaining: 15.3ms
# 125:	learn: 5.5660273	total: 77.1ms	remaining: 14.7ms
# 126:	learn: 5.5614418	total: 77.7ms	remaining: 14.1ms
# 127:	learn: 5.5564230	total: 78.3ms	remaining: 13.5ms
# 128:	learn: 5.5431261	total: 78.9ms	remaining: 12.8ms
# 129:	learn: 5.5358409	total: 79.5ms	remaining: 12.2ms
# 130:	learn: 5.5316933	total: 80.1ms	remaining: 11.6ms
# 131:	learn: 5.5299174	total: 80.7ms	remaining: 11ms
# 132:	learn: 5.5255534	total: 81.3ms	remaining: 10.4ms
# 133:	learn: 5.5224070	total: 82ms	remaining: 9.79ms
# 134:	learn: 5.5150347	total: 82.7ms	remaining: 9.19ms
# 135:	learn: 5.5114361	total: 83.3ms	remaining: 8.58ms
# 136:	learn: 5.5081380	total: 84ms	remaining: 7.97ms
# 137:	learn: 5.5031359	total: 84.6ms	remaining: 7.36ms
# 138:	learn: 5.4989330	total: 85.2ms	remaining: 6.74ms
# 139:	learn: 5.4943313	total: 85.8ms	remaining: 6.13ms
# 140:	learn: 5.4904198	total: 86.4ms	remaining: 5.51ms
# 141:	learn: 5.4860063	total: 87ms	remaining: 4.9ms
# 142:	learn: 5.4807846	total: 87.6ms	remaining: 4.29ms
# 143:	learn: 5.4768171	total: 88.2ms	remaining: 3.68ms
# 144:	learn: 5.4733916	total: 88.8ms	remaining: 3.06ms
# 145:	learn: 5.4703264	total: 89.5ms	remaining: 2.45ms
# 146:	learn: 5.4654326	total: 90.1ms	remaining: 1.84ms
# 147:	learn: 5.4615881	total: 90.7ms	remaining: 1.23ms
# 148:	learn: 5.4583122	total: 91.4ms	remaining: 613us
# 149:	learn: 5.4533134	total: 92ms	remaining: 0us
# CPU times: user 37.4 s, sys: 765 ms, total: 38.1 s
# Wall time: 52 s

# %%
print(f'Оптимальные гиперпараметры:\n{catboost_grid.best_params_}\n MAE: {final_metrics_CB}')
# Out:
# Оптимальные гиперпараметры:
# {'learning_rate': 0.1, 'iterations': 150, 'depth': 2}
#  MAE: {'learn': {'MAE': 5.453313369486456}}

# %% [markdown]
# <div style="padding: 30px 25px; border: 3px #7AD1FF solid">
#
# <p style="font-weight: bold; text-align: center;"> RandomForest

# %%
param_grid = {
    'n_estimators': [10,50,100, 150],
    'max_depth': [2,5,7,15],
    'min_samples_split': [2, 3,5,10],
}

pipe = RandomForestRegressor()

random_search_RF = RandomizedSearchCV(estimator=pipe,
                                      param_distributions=param_grid,
                                      cv=5,
                                      verbose=3,
                                      random_state=SEED,
                                       scoring = 'neg_mean_absolute_error'
                                     )

# %%
# %%time
# обучение модели
random_search_RF.fit(x_train, y_train)
# сохраним лучшую модель
best_model_RF = random_search_RF.best_estimator_
# сохраним лучшее значение метрики
final_metrics_RF = random_search_RF.best_score_
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END max_depth=15, min_samples_split=10, n_estimators=100; total time=   0.6s
# [CV 2/5] END max_depth=15, min_samples_split=10, n_estimators=100; total time=   0.7s
# [CV 3/5] END max_depth=15, min_samples_split=10, n_estimators=100; total time=   0.6s
# [CV 4/5] END max_depth=15, min_samples_split=10, n_estimators=100; total time=   0.6s
# [CV 5/5] END max_depth=15, min_samples_split=10, n_estimators=100; total time=   0.7s
# [CV 1/5] END max_depth=2, min_samples_split=10, n_estimators=150; total time=   0.3s
# [CV 2/5] END max_depth=2, min_samples_split=10, n_estimators=150; total time=   0.3s
# [CV 3/5] END max_depth=2, min_samples_split=10, n_estimators=150; total time=   0.3s
# [CV 4/5] END max_depth=2, min_samples_split=10, n_estimators=150; total time=   0.3s
# [CV 5/5] END max_depth=2, min_samples_split=10, n_estimators=150; total time=   0.3s
# [CV 1/5] END max_depth=5, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV 2/5] END max_depth=5, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV 3/5] END max_depth=5, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV 4/5] END max_depth=5, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV 5/5] END max_depth=5, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV 1/5] END max_depth=2, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV 2/5] END max_depth=2, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV 3/5] END max_depth=2, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV 4/5] END max_depth=2, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV 5/5] END max_depth=2, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV 1/5] END max_depth=5, min_samples_split=10, n_estimators=150; total time=   0.6s
# [CV 2/5] END max_depth=5, min_samples_split=10, n_estimators=150; total time=   0.6s
# [CV 3/5] END max_depth=5, min_samples_split=10, n_estimators=150; total time=   0.6s
# [CV 4/5] END max_depth=5, min_samples_split=10, n_estimators=150; total time=   0.5s
# [CV 5/5] END max_depth=5, min_samples_split=10, n_estimators=150; total time=   0.5s
# [CV 1/5] END max_depth=15, min_samples_split=2, n_estimators=50; total time=   0.4s
# [CV 2/5] END max_depth=15, min_samples_split=2, n_estimators=50; total time=   0.4s
# [CV 3/5] END max_depth=15, min_samples_split=2, n_estimators=50; total time=   0.4s
# [CV 4/5] END max_depth=15, min_samples_split=2, n_estimators=50; total time=   0.4s
# [CV 5/5] END max_depth=15, min_samples_split=2, n_estimators=50; total time=   0.4s
# [CV 1/5] END max_depth=5, min_samples_split=5, n_estimators=50; total time=   0.2s
# [CV 2/5] END max_depth=5, min_samples_split=5, n_estimators=50; total time=   0.2s
# [CV 3/5] END max_depth=5, min_samples_split=5, n_estimators=50; total time=   0.2s
# [CV 4/5] END max_depth=5, min_samples_split=5, n_estimators=50; total time=   0.2s
# [CV 5/5] END max_depth=5, min_samples_split=5, n_estimators=50; total time=   0.2s
# [CV 1/5] END max_depth=7, min_samples_split=10, n_estimators=50; total time=   0.3s
# [CV 2/5] END max_depth=7, min_samples_split=10, n_estimators=50; total time=   0.2s
# [CV 3/5] END max_depth=7, min_samples_split=10, n_estimators=50; total time=   0.2s
# [CV 4/5] END max_depth=7, min_samples_split=10, n_estimators=50; total time=   0.2s
# [CV 5/5] END max_depth=7, min_samples_split=10, n_estimators=50; total time=   0.2s
# [CV 1/5] END max_depth=7, min_samples_split=3, n_estimators=150; total time=   0.7s
# [CV 2/5] END max_depth=7, min_samples_split=3, n_estimators=150; total time=   0.8s
# [CV 3/5] END max_depth=7, min_samples_split=3, n_estimators=150; total time=   0.7s
# [CV 4/5] END max_depth=7, min_samples_split=3, n_estimators=150; total time=   0.7s
# [CV 5/5] END max_depth=7, min_samples_split=3, n_estimators=150; total time=   0.7s
# [CV 1/5] END max_depth=7, min_samples_split=2, n_estimators=150; total time=   0.7s
# [CV 2/5] END max_depth=7, min_samples_split=2, n_estimators=150; total time=   0.8s
# [CV 3/5] END max_depth=7, min_samples_split=2, n_estimators=150; total time=   0.7s
# [CV 4/5] END max_depth=7, min_samples_split=2, n_estimators=150; total time=   0.7s
# [CV 5/5] END max_depth=7, min_samples_split=2, n_estimators=150; total time=   0.7s
# CPU times: user 22.4 s, sys: 67.6 ms, total: 22.5 s
# Wall time: 22.6 s

# %%
print(f'Оптимальные гиперпараметры:\n{random_search_RF.best_params_}\n MAE: {final_metrics_RF}')
# Out:
# Оптимальные гиперпараметры:
# {'n_estimators': 100, 'min_samples_split': 10, 'max_depth': 15}
#  MAE: -5.956390403703844

# %% [markdown]
# <div style="padding: 30px 25px; border: 3px #7AD1FF solid">
#
# <p style="font-weight: bold; text-align: center;"> полносвязная сеть

# %%
X_train = torch.FloatTensor(np.array(x_train))
y_train = torch.FloatTensor(np.array(y_train))
X_test = torch.FloatTensor(np.array(x_test))
y_test = torch.FloatTensor(np.array(y_test))
print(X_train.shape)
print(X_test.shape)
print(y_train)
print(y_test)
# Out:
# torch.Size([1735, 12])
# torch.Size([579, 12])
# tensor([1586., 1599., 1596.,  ..., 1617., 1597., 1603.])
# tensor([1593., 1602., 1602., 1594., 1572., 1589., 1581., 1596., 1598., 1595.,
#         1596., 1573., 1600., 1609., 1579., 1583., 1595., 1623., 1599., 1609.,
#         1593., 1594., 1590., 1580., 1588., 1584., 1590., 1593., 1603., 1590.,
#         1594., 1573., 1594., 1603., 1594., 1593., 1587., 1592., 1598., 1598.,
#         1590., 1593., 1594., 1617., 1592., 1588., 1620., 1577., 1588., 1606.,
#         1599., 1595., 1592., 1587., 1590., 1600., 1589., 1605., 1586., 1599.,
#         1604., 1575., 1594., 1594., 1598., 1594., 1597., 1587., 1593., 1575.,
#         1589., 1595., 1597., 1599., 1578., 1585., 1624., 1575., 1603., 1610.,
#         1594., 1593., 1602., 1609., 1622., 1595., 1617., 1597., 1594., 1595.,
#         1596., 1576., 1599., 1592., 1575., 1580., 1598., 1613., 1601., 1600.,
#         1575., 1580., 1620., 1596., 1601., 1593., 1592., 1595., 1608., 1591.,
#         1602., 1595., 1593., 1591., 1609., 1593., 1592., 1589., 1597., 1587.,
#         1580., 1603., 1590., 1592., 1600., 1590., 1593., 1590., 1545., 1593.,
#         1575., 1591., 1605., 1582., 1586., 1597., 1590., 1580., 1581., 1590.,
#         1595., 1595., 1596., 1592., 1595., 1591., 1587., 1584., 1586., 1615.,
#         1594., 1579., 1595., 1595., 1598., 1592., 1599., 1573., 1591., 1591.,
#         1594., 1591., 1589., 1595., 1595., 1589., 1587., 1602., 1589., 1593.,
#         1608., 1618., 1590., 1595., 1596., 1599., 1594., 1585., 1593., 1600.,
#         1588., 1595., 1594., 1590., 1614., 1576., 1584., 1590., 1596., 1596.,
#         1584., 1593., 1599., 1586., 1621., 1592., 1582., 1603., 1595., 1592.,
#         1591., 1604., 1593., 1591., 1598., 1602., 1594., 1599., 1609., 1589.,
#         1600., 1596., 1583., 1590., 1594., 1586., 1576., 1617., 1595., 1596.,
#         1603., 1605., 1595., 1590., 1600., 1596., 1594., 1577., 1588., 1587.,
#         1592., 1592., 1593., 1594., 1597., 1593., 1580., 1589., 1592., 1588.,
#         1579., 1586., 1556., 1600., 1596., 1593., 1600., 1577., 1568., 1587.,
#         1607., 1592., 1594., 1587., 1585., 1621., 1586., 1592., 1601., 1588.,
#         1588., 1592., 1597., 1575., 1574., 1597., 1578., 1613., 1607., 1620.,
#         1610., 1600., 1612., 1610., 1602., 1589., 1613., 1582., 1594., 1586.,
#         1576., 1591., 1595., 1599., 1620., 1617., 1592., 1622., 1594., 1597.,
#         1595., 1594., 1595., 1592., 1599., 1589., 1582., 1594., 1586., 1595.,
#         1618., 1594., 1591., 1607., 1584., 1596., 1576., 1594., 1585., 1585.,
#         1603., 1607., 1583., 1618., 1618., 1585., 1591., 1598., 1608., 1575.,
#         1589., 1598., 1580., 1594., 1593., 1580., 1577., 1576., 1596., 1596.,
#         1580., 1596., 1584., 1586., 1594., 1602., 1592., 1575., 1590., 1611.,
#         1591., 1597., 1585., 1591., 1578., 1617., 1612., 1590., 1590., 1599.,
#         1589., 1580., 1586., 1594., 1601., 1580., 1595., 1589., 1595., 1566.,
#         1595., 1581., 1592., 1601., 1597., 1595., 1584., 1595., 1594., 1581.,
#         1602., 1587., 1602., 1554., 1592., 1623., 1589., 1610., 1590., 1596.,
#         1608., 1589., 1617., 1591., 1577., 1589., 1592., 1592., 1601., 1598.,
#         1599., 1595., 1591., 1574., 1601., 1616., 1585., 1598., 1610., 1580.,
#         1602., 1581., 1610., 1586., 1591., 1576., 1585., 1595., 1592., 1593.,
#         1582., 1605., 1580., 1594., 1592., 1594., 1599., 1616., 1595., 1583.,
#         1575., 1596., 1588., 1589., 1590., 1605., 1597., 1585., 1598., 1591.,
#         1594., 1575., 1580., 1584., 1589., 1603., 1599., 1583., 1594., 1575.,
#         1605., 1587., 1599., 1580., 1595., 1604., 1587., 1581., 1581., 1586.,
#         1602., 1582., 1587., 1591., 1584., 1618., 1591., 1619., 1623., 1580.,
#         1591., 1591., 1598., 1596., 1575., 1596., 1591., 1590., 1587., 1593.,
#         1592., 1609., 1593., 1591., 1597., 1597., 1594., 1592., 1583., 1585.,
#         1578., 1595., 1615., 1583., 1584., 1590., 1590., 1594., 1587., 1599.,
#         1590., 1589., 1601., 1582., 1609., 1601., 1585., 1600., 1591., 1602.,
#         1582., 1605., 1607., 1615., 1597., 1592., 1592., 1593., 1597., 1579.,
#         1585., 1585., 1606., 1615., 1596., 1605., 1647., 1601., 1587., 1591.,
#         1595., 1611., 1607., 1594., 1583., 1590., 1593., 1591., 1595., 1620.,
#         1599., 1601., 1599., 1579., 1578., 1602., 1585., 1587., 1591., 1589.,
#         1595., 1591., 1579., 1592., 1589., 1598., 1619., 1575., 1575., 1590.,
#         1595., 1593., 1585., 1592., 1597., 1606., 1591., 1614., 1597., 1596.,
#         1593., 1589., 1578., 1586., 1593., 1586., 1586., 1580., 1628., 1601.,
#         1579., 1598., 1603., 1593., 1598., 1599., 1594., 1597., 1620.])

# %%
train_dataset = TensorDataset(X_train, y_train)
train_loader = DataLoader(train_dataset, batch_size=64)

# %%
class Net(nn.Module):
    def __init__(self, input_dim, hidden_dims, output_dim):
        super(Net, self).__init__()

        layers = []
        in_dim = input_dim
        for out_dim in hidden_dims:
            layers.append(nn.Linear(in_dim, out_dim))
            layers.append(nn.BatchNorm1d(out_dim))
            layers.append(nn.ReLU())
            in_dim = out_dim

        layers.append(nn.Linear(hidden_dims[-1], output_dim))
        layers.append(nn.Sigmoid())

        self.net = nn.Sequential(*layers)
        # Инициализация весов
        for m in self.net:
            if isinstance(m, nn.Linear):
                nn.init.kaiming_uniform_(m.weight, mode='fan_in', nonlinearity='relu')

    def forward(self, x):
        return self.net(x)

# %%
hidden_dims = [1024, 512, 256, 16,1]
net = Net(X_train.shape[1], hidden_dims, 1)

optimizer = torch.optim.Adam(net.parameters(), lr=1e-2)
loss_func = nn.L1Loss()

# %%
num_epochs = 50
best_mae = float('inf')
best_mae_train = float('inf')

for epoch in range(num_epochs):
    net.train()

    for X_batch, y_batch in train_loader:
        optimizer.zero_grad()
        preds = net(X_batch).flatten()
        loss_value = loss_func(preds, y_batch)
        loss_value.backward()
        optimizer.step()

    with torch.no_grad():
        net.eval()
        test_preds = net(X_test).flatten()
        mae = loss_func(test_preds, y_test)
        best_mae = min(best_mae, mae.item())

        mae_train = loss_value.item()
        best_mae_train = min(best_mae_train, mae_train)

        if epoch % 10 == 0 or epoch == num_epochs - 1:
            print(f'Epoch {epoch}, MAE: {mae:.4f}, MAE_train: {mae_train:.4f}')

#print(f'Best MAE on test set: {best_mae:.4f}')
print(f'Best MAE on training set: {best_mae_train:.4f}')
# Out:
# Epoch 0, MAE: 1592.5929, MAE_train: 1598.8939
# Epoch 10, MAE: 1592.5651, MAE_train: 1598.8734
# Epoch 20, MAE: 1592.5637, MAE_train: 1598.8693
# Epoch 30, MAE: 1592.5623, MAE_train: 1598.8588
# Epoch 40, MAE: 1592.5604, MAE_train: 1598.8577
# Epoch 49, MAE: 1592.5604, MAE_train: 1598.8573
# Best MAE on training set: 1598.8573

# %%
predictive_model_scores = pd.DataFrame(data= [
                                              ('Linear Regression',mean_absolute_error(y_train, lr_grid.predict(X_train.numpy()))),
                                              ('Lasso', mean_absolute_error(y_train, lr_lasso_grid.predict(X_train.numpy()))),
                                              ('CatBoost',mean_absolute_error(y_train, best_model_CB.predict(X_train.numpy()))),
                                              ('RandomForest',mean_absolute_error(y_train, best_model_RF.predict(X_train.numpy()))),
                                              ('fully connected net',best_mae_train)
                                                ],

                                       columns=['model', 'train_MAE'])

predictive_model_scores=predictive_model_scores.set_index('model')

predictive_model_scores
# Out:
#                        train_MAE
# model
# Linear Regression       6.595455
# Lasso                   5.732632
# CatBoost                5.453314
# RandomForest            3.247849
# fully connected net  1598.857300

# %% [markdown]
# <div style="padding: 30px 25px; border: 3px #7AD1FF solid">
#
# <p style="font-weight: bold; text-align: center;"> вывод <p>
#
# - протестировали 4 модели
# -лучшая модель RandomForest, ее и будем использовать для финального тестирования

# %% [markdown]
# <div style="font-size:30px ;padding: 30px 25px; background-color:#7AD1FF ;solid;font-weight:400">
# <p style="font-weight: bold; text-align: center;"> глава 4. тест лучшей модели

# %%
pred=best_model_RF.predict(x_test)
print(f'MAE: {mean_absolute_error(y_test,pred)} R2: {r2_score(y_test,pred)}')
# Out:
# MAE: 5.766153784691428 R2: 0.4791388516237912

# %%
dummy_regr = DummyRegressor(strategy='median')
dummy_regr.fit(X_train, y_train)
# Out:
# DummyRegressor(strategy='median')

# %%
const_pred=dummy_regr.predict(X_test)

# %%
R2=dummy_regr.score(x_test,y_test)

# %%
print(f'MAE: {mean_absolute_error(y_test,const_pred)} R2: {R2}')
# Out:
# MAE: 8.034542083740234 R2: -0.002516226054771753

# %%
plt.figure(figsize=(30, 30))

sns.histplot(pred, color='red',bins=50)
sns.histplot(y_test,color='black',alpha=0.5,bins=50)

plt.title('разница между истиными и предсказанными данными',size=30)
plt.xlabel('температура',size=30)
plt.ylabel('количество записей',size=30);

# %%
feature_names = features.columns
importances = best_model_RF.feature_importances_
model_importances = pd.Series(importances, index=feature_names)

std = np.std([best_model_RF.feature_importances_ for tree in str(1000)], axis=0)

fig, ax = plt.subplots(figsize=(10,7))
model_importances.plot.bar(yerr=std, ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel("среднее значение важности")
ax.set_xlabel("имя признака")
fig.tight_layout()

# %% [markdown]
# <div style="padding: 30px 25px; border: 3px #7AD1FF solid">
#
# <p style="font-weight: bold; text-align: center;"> вывод <p>
#
# - протестировали лучшую модель и сравнили её с константной моделью по метрике R2 и MAE.
#     - MAE у рандом форест (лучшая модель) оказалось меньше (значит лучше)
#     - R2 у рандом форест (лучшая модель) оказалось больше (значит лучше)
#     - также R2 у обеих моделей меньше 1 и не равна 0 это значит, что они работают правильно
#
# - модель рандом фореста показал хороший результат:
#     - MAE:  5.75
#     - R2:   0.42
#
# ---
# <p style="font-weight: bold; text-align: center;"> анализ важности признаков для обучения модели <p>
#
# - самым важным признаком оказалась первая температура
# - второй по важности признак, но не менее важным, чем первый это полная мощность ( не удивительно т.к. вполне логично, что чем больше подать мощности на электроды тем выше получиться выходная температура и быстрее расплавится металл)
# - третий по важности признак это разница во времени и температуре (time_temp_diff)
# - четвертое место поделили 2 признака это присадочный материал 6 и проволока 1
#
# - самыми мало значемыми признаками стали: присадочный материал 3 и присадочный материал 4 ( в них довольно много пропусков было по этому это было ожидаемо)

# %% [markdown]
# <div style="font-size:30px ;padding: 30px 25px; background-color:#7AD1FF ;solid;font-weight:400">
# <p style="font-weight: bold; text-align: center;"> Глава 5. Общий вывод

# %% [markdown]
# <div style=" padding: 30px 25px; border: 3px #FFBF73 solid">
#
# __Цель__:
#
# На основании данных о процессе нагрева стали (температуры сплава на различных этапах нагрева, добавленные добавки в сплав, объем использованного газа), необходимо было построить модель, которая предскажет температуру нагрева сплава стали на финальном этапе, с показателем метрики MAE <= 6.8
#
# __Выполненные шаги__:
#
# - Данные были очищены от нерелевантных значений, пропуски заполнены, аномалии проанализированы
# - Проведен графический, корелляционный и аналитический анализ данных
# - Созданы дополнительные признаки на основе имеющихся данных
# - Построены модели - линейная регрессия, случайный лес, полносвязная нейроная сеть, CatBoost
# - лучшее значение метрики дала модель  RandomForest MAE:(3.28)
#
# __Результат проверки модели на тестовой выборке__:
#
# - модель не показала существенного ухудшения метрики на тестовой выборке (5,75), R2(0,42)
# - лучшая модель была сравнена с константной моделью тем самым доказав свою работоспособность
# - был построен график на котором нагрядно видно истинные значения и предсказанные
#
# __рекомендации заказчику по улучщению модели__:
# - привести БД в порядок и убрать лишние записи по подаче материала и проволоки
# - посмотреть целостность оборудования для измерения показателей
# - также стоит обратить пристальное внимание на пораметры реактивной и активной мощьности т.к. судя по данным там твариться чтото странное.
#
# __Итоговый вывод__:
# - разработанная модель  удовлетворяет запросу заказчика, по этому ее смело можно внедрить в технологический процесс и начать экономить электро энергию.
